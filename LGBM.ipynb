# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings(action='ignore')

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import f1_score
from sklearn.preprocessing import OneHotEncoder

from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier




import os

# %%
# 데이터 불러오기
train = pd.read_csv('/kaggle/input/kakr-4th-competition/train.csv')
test = pd.read_csv('/kaggle/input/kakr-4th-competition/test.csv')
sample_submission = pd.read_csv('../input/kakr-4th-competition/sample_submission.csv')

label = train['income']

del train['income']

# %%
# 라벨 값 인코딩
label = label.map(lambda x: 1 if x == '>50K' else 0)

# %%
x_train, x_valid, y_train, y_valid = train_test_split(train, label, 
                                                          test_size=0.2,
                                                          random_state=20,
                                                          shuffle=True)

# %%
def preprocess(x_train, x_valid, x_test):
    
    global tmp_x_train
    global tmp_x_valid
    global tmp_x_test
    
    tmp_x_train = x_train.copy()
    tmp_x_valid = x_valid.copy()
    tmp_x_test  = x_test.copy()
    
    tmp_x_train = tmp_x_train.reset_index(drop=True)
    tmp_x_valid = tmp_x_valid.reset_index(drop=True)
    tmp_x_test  = tmp_x_test.reset_index(drop=True)
    
    # column 제거
    tmp_x_train.drop(['id','fnlwgt','education','relationship','native_country','workclass'], axis=1, inplace=True)
    tmp_x_valid.drop(['id','fnlwgt','education','relationship','native_country','workclass'], axis=1, inplace=True)
    tmp_x_test.drop(['id','fnlwgt','education','relationship','native_country','workclass'], axis=1, inplace=True)
    
    # marital status
    tmp_x_train['marital_status'] = (tmp_x_train['marital_status'] == 'Married-civ-spouse').astype(int)
    tmp_x_valid['marital_status'] = (tmp_x_valid['marital_status'] == 'Married-civ-spouse').astype(int)
    tmp_x_test['marital_status'] = (tmp_x_test['marital_status'] == 'Married-civ-spouse').astype(int)
    
    # race
    tmp_x_train['race'] = ((tmp_x_train['race'] == 'White') | (tmp_x_train['race'] == 'Asian-Pac-Islander')).astype(int)
    tmp_x_valid['race'] = ((tmp_x_valid['race'] == 'White') | (tmp_x_valid['race'] == 'Asian-Pac-Islander')).astype(int)
    tmp_x_test['race'] = ((tmp_x_test['race'] == 'White') | (tmp_x_test['race'] == 'Asian-Pac-Islander')).astype(int)
    
    # capital_gain, loss
    tmp_x_train['cap_gain_high'] = (tmp_x_train['capital_gain'] != 0).astype(int)
    tmp_x_train['cap_loss_high'] = (tmp_x_train['capital_loss'] >= 1700).astype(int)
    tmp_x_train['capital_gain'] = tmp_x_train['capital_gain'].map(lambda x : np.log(x) if x != 0 else 0)
    
    tmp_x_valid['cap_gain_high'] = (tmp_x_valid['capital_gain'] != 0).astype(int)
    tmp_x_valid['cap_loss_high'] = (tmp_x_valid['capital_loss'] >= 1700).astype(int)
    tmp_x_valid['capital_gain'] = tmp_x_valid['capital_gain'].map(lambda x : np.log(x) if x != 0 else 0)
    
    tmp_x_test['cap_gain_high'] = (tmp_x_test['capital_gain'] != 0).astype(int)
    tmp_x_test['cap_loss_high'] = (tmp_x_test['capital_loss'] >= 1700).astype(int)
    tmp_x_test['capital_gain'] = tmp_x_test['capital_gain'].map(lambda x : np.log(x) if x != 0 else 0)
    
    # age
    tmp_x_train.loc[tmp_x_train['age'] < 20, 'age_range'] = '~20'
    tmp_x_train.loc[tmp_x_train['age'] >= 65, 'age_range'] = '~65'
    down = 20
    for i in range(45//5):
        tmp_x_train.loc[(tmp_x_train['age'] >= down) & (tmp_x_train['age'] < down+5), 'age_range'] = str(down)+'~'+str(down+5)
        down += 5
    tmp_x_train['age'] = tmp_x_train['age_range']
    tmp_x_train.drop(['age_range'], axis=1, inplace=True)
    
    tmp_x_valid.loc[tmp_x_valid['age'] < 20, 'age_range'] = '~20'
    tmp_x_valid.loc[tmp_x_valid['age'] >= 65, 'age_range'] = '~65'
    down = 20
    for i in range(45//5):
        tmp_x_valid.loc[(tmp_x_valid['age'] >= down) & (tmp_x_valid['age'] < down+5), 'age_range'] = str(down)+'~'+str(down+5)
        down += 5
    tmp_x_valid['age'] = tmp_x_valid['age_range']
    tmp_x_valid.drop(['age_range'], axis=1, inplace=True)
    
    tmp_x_test.loc[tmp_x_test['age'] < 20, 'age_range'] = '~20'
    tmp_x_test.loc[tmp_x_test['age'] >= 65, 'age_range'] = '~65'
    down = 20
    for i in range(45//5):
        tmp_x_test.loc[(tmp_x_test['age'] >= down) & (tmp_x_test['age'] < down+5), 'age_range'] = str(down)+'~'+str(down+5)
        down += 5
    tmp_x_test['age'] = tmp_x_test['age_range']
    tmp_x_test.drop(['age_range'], axis=1, inplace=True)
        
    # edu_num
    tmp_x_train['edu_num_high'] = (tmp_x_train['education_num'] >= 13).astype(int)
    tmp_x_valid['edu_num_high'] = (tmp_x_valid['education_num'] >= 13).astype(int)
    tmp_x_test['edu_num_high'] = (tmp_x_test['education_num'] >= 13).astype(int)
    
    # hours-per-week
    tmp_x_train['hpw_high'] = (tmp_x_train['hours_per_week'] >= 50).astype(int)
    tmp_x_valid['hpw_high'] = (tmp_x_valid['hours_per_week'] >= 50).astype(int)
    tmp_x_test['hpw_high'] = (tmp_x_test['hours_per_week'] >= 50).astype(int)
    
    # min-max scaler
    mmscaler = MinMaxScaler()
    tmp_x_train['education_num'] = mmscaler.fit_transform(tmp_x_train['education_num'].values.reshape(-1,1))
    tmp_x_valid['education_num'] = mmscaler.transform(tmp_x_valid['education_num'].values.reshape(-1,1))
    tmp_x_test['education_num'] = mmscaler.transform(tmp_x_test['education_num'].values.reshape(-1,1))
    
    tmp_x_train['hours_per_week'] = mmscaler.transform(tmp_x_train['hours_per_week'].values.reshape(-1,1))
    tmp_x_valid['hours_per_week'] = mmscaler.transform(tmp_x_valid['hours_per_week'].values.reshape(-1,1))
    tmp_x_test['hours_per_week'] = mmscaler.transform(tmp_x_test['hours_per_week'].values.reshape(-1,1))

    
    # ohe
    tmp_all = pd.concat([tmp_x_train, tmp_x_valid, tmp_x_test])
    
    ohe = OneHotEncoder(sparse=False)
    cat_columns = ['age', 'marital_status', 'occupation', 'race', 'sex']
    ohe.fit(tmp_all[cat_columns])
    
    
    ohe_columns = list()
    for lst in ohe.categories_:
        ohe_columns += lst.tolist()
    
    tmp_train_cat = pd.DataFrame(ohe.transform(tmp_x_train[cat_columns]), columns=ohe_columns)
    tmp_valid_cat = pd.DataFrame(ohe.transform(tmp_x_valid[cat_columns]), columns=ohe_columns)
    tmp_test_cat  = pd.DataFrame(ohe.transform(tmp_x_test[cat_columns]), columns=ohe_columns)
    
    tmp_train_cat.columns = ohe.get_feature_names(cat_columns)
    tmp_valid_cat.columns = ohe.get_feature_names(cat_columns)
    tmp_test_cat.columns = ohe.get_feature_names(cat_columns)
    
    tmp_x_train = pd.concat([tmp_x_train, tmp_train_cat], axis=1)
    tmp_x_valid = pd.concat([tmp_x_valid, tmp_valid_cat], axis=1)
    tmp_x_test = pd.concat([tmp_x_test, tmp_test_cat], axis=1)

    tmp_x_train = tmp_x_train.drop(columns=cat_columns)
    tmp_x_valid = tmp_x_valid.drop(columns=cat_columns)
    tmp_x_test = tmp_x_test.drop(columns=cat_columns)
        
#     # get_dummies
#     tmp_x_train = pd.get_dummies(tmp_x_train, columns = ['age', 'marital_status', 'occupation', 'race', 'sex'])
#     tmp_x_valid = pd.get_dummies(tmp_x_valid, columns = ['age', 'marital_status', 'occupation', 'race', 'sex'])
#     tmp_x_test = pd.get_dummies(tmp_x_test, columns = ['age', 'marital_status', 'occupation', 'race', 'sex'])
    
    
    return tmp_x_train.values, tmp_x_valid.values, tmp_x_test.values

# %%
preprocess(x_train, x_valid, test)
# Out:
# (array([[0.66666667, 0.        , 0.        , ..., 1.        , 0.        ,
#          1.        ],
#         [0.53333333, 0.        , 0.        , ..., 1.        , 0.        ,
#          1.        ],
#         [0.53333333, 0.        , 0.        , ..., 1.        , 0.        ,
#          1.        ],
#         ...,
#         [0.8       , 0.        , 0.        , ..., 1.        , 1.        ,
#          0.        ],
#         [0.8       , 0.        , 0.        , ..., 1.        , 0.        ,
#          1.        ],
#         [0.53333333, 0.        , 0.        , ..., 1.        , 0.        ,
#          1.        ]]),
#  array([[0.53333333, 0.        , 0.        , ..., 1.        , 1.        ,
#          0.        ],
#         [0.86666667, 0.        , 0.        , ..., 0.        , 0.        ,
#          1.        ],
#         [0.6       , 0.        , 0.        , ..., 1.        , 0.        ,
#          1.        ],
#         ...,
#         [0.53333333, 0.        , 0.        , ..., 1.        , 1.        ,
#          0.        ],
#         [0.8       , 8.94741595, 0.        , ..., 1.        , 0.        ,
#          1.        ],
#         [0.86666667, 0.        , 0.        , ..., 1.        , 0.        ,
#          1.        ]]),
#  array([[0.6       , 0.        , 0.        , ..., 1.        , 1.        ,
#          0.        ],
#         [0.53333333, 0.        , 0.        , ..., 1.        , 0.        ,
#          1.        ],
#         [0.6       , 0.        , 0.        , ..., 1.        , 0.        ,
#          1.        ],
#         ...,
#         [0.13333333, 0.        , 0.        , ..., 1.        , 0.        ,
#          1.        ],
#         [0.53333333, 0.        , 0.        , ..., 1.        , 0.        ,
#          1.        ],
#         [0.53333333, 0.        , 0.        , ..., 1.        , 1.        ,
#          0.        ]]))

# %% [markdown]
# # Simple LGBM

# %%
lgb = LGBMClassifier(tree_method='gpu_hist')

lgb.fit(tmp_x_train, y_train)

y_pred = lgb.predict(tmp_x_valid)

print(f"LightGBM F1 Score: {f1_score(y_valid, y_pred, average='micro')}")
# Out:
# LightGBM F1 Score: 0.8690978886756238

# %%
# light GBM
from sklearn.model_selection import StratifiedKFold
n_splits = 5
skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=2020)


val_scores = list()
oof_pred = np.zeros((test.shape[0], )) # 이것도 달라짐

for i, (trn_idx, val_idx) in enumerate(skf.split(train, label)):
    x_train, y_train = train.iloc[trn_idx, :], label[trn_idx]
    x_valid, y_valid = train.iloc[val_idx, :], label[val_idx]
    
    # 전처리
    x_train, x_valid, x_test = preprocess(x_train, x_valid, test)
    
    # 모델 정의
    clf = LGBMClassifier(tree_method='gpu_hist')
    
    # 모델 학습
    clf.fit(x_train, y_train,
            eval_set = [[x_valid, y_valid]], 
            eval_metric = 'logloss',        
            early_stopping_rounds = 100,
            verbose = 100,  )

    # 훈련, 검증 데이터 F1 Score 확인
    trn_f1_score = f1_score(y_train, clf.predict(x_train), average='micro')
    val_f1_score = f1_score(y_valid, clf.predict(x_valid), average='micro')
    print('{} Fold, train f1_score : {:.4f}4, validation f1_score : {:.4f}\n'.format(i, trn_f1_score, val_f1_score))
    
    val_scores.append(val_f1_score)
    
    oof_pred += clf.predict_proba(x_test)[: , 1] / n_splits # 이게 달라진거임
    

# 교차 검증 F1 Score 평균 계산하기
print('Cross Validation Score : {:.4f}'.format(np.mean(val_scores)))
# Out:
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.280645
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's binary_logloss: 0.280645
# 0 Fold, train f1_score : 0.87984, validation f1_score : 0.8695
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.28152
# Did not meet early stopping. Best iteration is:
# [99]	valid_0's binary_logloss: 0.281508
# 1 Fold, train f1_score : 0.88144, validation f1_score : 0.8670
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.285252
# Did not meet early stopping. Best iteration is:
# [95]	valid_0's binary_logloss: 0.285136
# 2 Fold, train f1_score : 0.88094, validation f1_score : 0.8651
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.283011
# Did not meet early stopping. Best iteration is:
# [98]	valid_0's binary_logloss: 0.282902
# 3 Fold, train f1_score : 0.88134, validation f1_score : 0.8656
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.278725
# Did not meet early stopping. Best iteration is:
# [97]	valid_0's binary_logloss: 0.278615
# 4 Fold, train f1_score : 0.87984, validation f1_score : 0.8702
#
# Cross Validation Score : 0.8675

# %% [markdown]
# ## Hyper-parameter tuning

# %%
# 책에 나와있는 것

lgbm_wrapper = LGBMClassifier(n_estimators = 400)

evals = [(tmp_x_valid, y_valid)]
lgbm_wrapper.fit(tmp_x_valid, y_valid, early_stopping_rounds = 100, eval_metric = 'logloss',
                eval_set = evals, verbose = True)
preds = lgbm_wrapper.predict(tmp_x_valid)
# Out:
# [1]	training's binary_logloss: 0.50894
# Training until validation scores don't improve for 100 rounds
# [2]	training's binary_logloss: 0.476117
# [3]	training's binary_logloss: 0.449627
# [4]	training's binary_logloss: 0.427759
# [5]	training's binary_logloss: 0.409123
# [6]	training's binary_logloss: 0.393423
# [7]	training's binary_logloss: 0.380252
# [8]	training's binary_logloss: 0.368393
# [9]	training's binary_logloss: 0.357875
# [10]	training's binary_logloss: 0.348628
# [11]	training's binary_logloss: 0.340411
# [12]	training's binary_logloss: 0.332938
# [13]	training's binary_logloss: 0.32669
# [14]	training's binary_logloss: 0.32097
# [15]	training's binary_logloss: 0.315906
# [16]	training's binary_logloss: 0.31084
# [17]	training's binary_logloss: 0.306664
# [18]	training's binary_logloss: 0.302686
# [19]	training's binary_logloss: 0.299266
# [20]	training's binary_logloss: 0.295322
# [21]	training's binary_logloss: 0.291826
# [22]	training's binary_logloss: 0.289123
# [23]	training's binary_logloss: 0.286385
# [24]	training's binary_logloss: 0.283593
# [25]	training's binary_logloss: 0.28113
# [26]	training's binary_logloss: 0.278567
# [27]	training's binary_logloss: 0.276295
# [28]	training's binary_logloss: 0.274059
# [29]	training's binary_logloss: 0.272023
# [30]	training's binary_logloss: 0.270105
# [31]	training's binary_logloss: 0.267917
# [32]	training's binary_logloss: 0.266075
# [33]	training's binary_logloss: 0.264611
# [34]	training's binary_logloss: 0.262994
# [35]	training's binary_logloss: 0.261637
# [36]	training's binary_logloss: 0.260341
# [37]	training's binary_logloss: 0.259069
# [38]	training's binary_logloss: 0.257855
# [39]	training's binary_logloss: 0.256704
# [40]	training's binary_logloss: 0.255741
# [41]	training's binary_logloss: 0.254694
# [42]	training's binary_logloss: 0.253638
# [43]	training's binary_logloss: 0.252675
# [44]	training's binary_logloss: 0.251636
# [45]	training's binary_logloss: 0.250684
# [46]	training's binary_logloss: 0.249711
# [47]	training's binary_logloss: 0.248701
# [48]	training's binary_logloss: 0.247856
# [49]	training's binary_logloss: 0.246983
# [50]	training's binary_logloss: 0.245814
# [51]	training's binary_logloss: 0.24483
# [52]	training's binary_logloss: 0.244025
# [53]	training's binary_logloss: 0.243235
# [54]	training's binary_logloss: 0.242442
# [55]	training's binary_logloss: 0.241414
# [56]	training's binary_logloss: 0.240765
# [57]	training's binary_logloss: 0.239984
# [58]	training's binary_logloss: 0.239171
# [59]	training's binary_logloss: 0.238535
# [60]	training's binary_logloss: 0.237856
# [61]	training's binary_logloss: 0.237108
# [62]	training's binary_logloss: 0.236528
# [63]	training's binary_logloss: 0.235906
# [64]	training's binary_logloss: 0.235278
# [65]	training's binary_logloss: 0.23465
# [66]	training's binary_logloss: 0.234092
# [67]	training's binary_logloss: 0.233565
# [68]	training's binary_logloss: 0.233049
# [69]	training's binary_logloss: 0.232299
# [70]	training's binary_logloss: 0.231695
# [71]	training's binary_logloss: 0.23092
# [72]	training's binary_logloss: 0.230394
# [73]	training's binary_logloss: 0.229831
# [74]	training's binary_logloss: 0.229009
# [75]	training's binary_logloss: 0.228336
# [76]	training's binary_logloss: 0.227874
# [77]	training's binary_logloss: 0.22734
# [78]	training's binary_logloss: 0.226787
# [79]	training's binary_logloss: 0.226428
# [80]	training's binary_logloss: 0.22588
# [81]	training's binary_logloss: 0.225361
# [82]	training's binary_logloss: 0.224803
# [83]	training's binary_logloss: 0.22431
# [84]	training's binary_logloss: 0.223847
# [85]	training's binary_logloss: 0.22353
# [86]	training's binary_logloss: 0.223078
# [87]	training's binary_logloss: 0.222534
# [88]	training's binary_logloss: 0.222157
# [89]	training's binary_logloss: 0.22172
# [90]	training's binary_logloss: 0.221086
# [91]	training's binary_logloss: 0.220558
# [92]	training's binary_logloss: 0.220164
# [93]	training's binary_logloss: 0.219799
# [94]	training's binary_logloss: 0.219292
# [95]	training's binary_logloss: 0.218948
# [96]	training's binary_logloss: 0.218525
# [97]	training's binary_logloss: 0.218095
# [98]	training's binary_logloss: 0.217694
# [99]	training's binary_logloss: 0.217423
# [100]	training's binary_logloss: 0.217119
# [101]	training's binary_logloss: 0.216793
# [102]	training's binary_logloss: 0.216432
# [103]	training's binary_logloss: 0.216072
# [104]	training's binary_logloss: 0.215504
# [105]	training's binary_logloss: 0.215098
# [106]	training's binary_logloss: 0.214619
# [107]	training's binary_logloss: 0.214302
# [108]	training's binary_logloss: 0.214013
# [109]	training's binary_logloss: 0.213618
# [110]	training's binary_logloss: 0.2129
# [111]	training's binary_logloss: 0.212686
# [112]	training's binary_logloss: 0.212298
# [113]	training's binary_logloss: 0.2119
# [114]	training's binary_logloss: 0.21167
# [115]	training's binary_logloss: 0.211358
# [116]	training's binary_logloss: 0.211091
# [117]	training's binary_logloss: 0.210595
# [118]	training's binary_logloss: 0.210238
# [119]	training's binary_logloss: 0.209981
# [120]	training's binary_logloss: 0.209613
# [121]	training's binary_logloss: 0.20937
# [122]	training's binary_logloss: 0.209041
# [123]	training's binary_logloss: 0.208675
# [124]	training's binary_logloss: 0.208483
# [125]	training's binary_logloss: 0.208106
# [126]	training's binary_logloss: 0.207827
# [127]	training's binary_logloss: 0.207242
# [128]	training's binary_logloss: 0.206954
# [129]	training's binary_logloss: 0.206766
# [130]	training's binary_logloss: 0.206303
# [131]	training's binary_logloss: 0.206042
# [132]	training's binary_logloss: 0.205726
# [133]	training's binary_logloss: 0.205449
# [134]	training's binary_logloss: 0.205108
# [135]	training's binary_logloss: 0.204489
# [136]	training's binary_logloss: 0.204217
# [137]	training's binary_logloss: 0.203855
# [138]	training's binary_logloss: 0.203446
# [139]	training's binary_logloss: 0.203244
# [140]	training's binary_logloss: 0.203093
# [141]	training's binary_logloss: 0.202793
# [142]	training's binary_logloss: 0.202582
# [143]	training's binary_logloss: 0.20218
# [144]	training's binary_logloss: 0.201739
# [145]	training's binary_logloss: 0.201484
# [146]	training's binary_logloss: 0.201087
# [147]	training's binary_logloss: 0.200684
# [148]	training's binary_logloss: 0.200499
# [149]	training's binary_logloss: 0.200188
# [150]	training's binary_logloss: 0.199814
# [151]	training's binary_logloss: 0.199548
# [152]	training's binary_logloss: 0.199363
# [153]	training's binary_logloss: 0.199037
# [154]	training's binary_logloss: 0.198764
# [155]	training's binary_logloss: 0.198496
# [156]	training's binary_logloss: 0.198282
# [157]	training's binary_logloss: 0.198073
# [158]	training's binary_logloss: 0.197735
# [159]	training's binary_logloss: 0.197324
# [160]	training's binary_logloss: 0.196745
# [161]	training's binary_logloss: 0.196479
# [162]	training's binary_logloss: 0.19618
# [163]	training's binary_logloss: 0.195934
# [164]	training's binary_logloss: 0.195747
# [165]	training's binary_logloss: 0.195452
# [166]	training's binary_logloss: 0.195222
# [167]	training's binary_logloss: 0.194984
# [168]	training's binary_logloss: 0.194625
# [169]	training's binary_logloss: 0.194378
# [170]	training's binary_logloss: 0.194103
# [171]	training's binary_logloss: 0.193863
# [172]	training's binary_logloss: 0.19372
# [173]	training's binary_logloss: 0.193496
# [174]	training's binary_logloss: 0.193286
# [175]	training's binary_logloss: 0.192894
# [176]	training's binary_logloss: 0.192462
# [177]	training's binary_logloss: 0.192249
# [178]	training's binary_logloss: 0.192032
# [179]	training's binary_logloss: 0.191698
# [180]	training's binary_logloss: 0.191368
# [181]	training's binary_logloss: 0.191158
# [182]	training's binary_logloss: 0.190844
# [183]	training's binary_logloss: 0.190597
# [184]	training's binary_logloss: 0.190352
# [185]	training's binary_logloss: 0.190069
# [186]	training's binary_logloss: 0.18987
# [187]	training's binary_logloss: 0.189668
# [188]	training's binary_logloss: 0.189422
# [189]	training's binary_logloss: 0.18919
# [190]	training's binary_logloss: 0.18899
# [191]	training's binary_logloss: 0.188698
# [192]	training's binary_logloss: 0.188508
# [193]	training's binary_logloss: 0.188249
# [194]	training's binary_logloss: 0.188124
# [195]	training's binary_logloss: 0.187846
# [196]	training's binary_logloss: 0.187621
# [197]	training's binary_logloss: 0.187358
# [198]	training's binary_logloss: 0.187183
# [199]	training's binary_logloss: 0.186864
# [200]	training's binary_logloss: 0.186616
# [201]	training's binary_logloss: 0.186358
# [202]	training's binary_logloss: 0.186082
# [203]	training's binary_logloss: 0.185918
# [204]	training's binary_logloss: 0.185756
# [205]	training's binary_logloss: 0.185579
# [206]	training's binary_logloss: 0.185234
# [207]	training's binary_logloss: 0.18486
# [208]	training's binary_logloss: 0.184702
# [209]	training's binary_logloss: 0.18438
# [210]	training's binary_logloss: 0.184165
# [211]	training's binary_logloss: 0.183947
# [212]	training's binary_logloss: 0.18369
# [213]	training's binary_logloss: 0.183435
# [214]	training's binary_logloss: 0.183194
# [215]	training's binary_logloss: 0.182866
# [216]	training's binary_logloss: 0.182674
# [217]	training's binary_logloss: 0.182469
# [218]	training's binary_logloss: 0.18228
# [219]	training's binary_logloss: 0.182117
# [220]	training's binary_logloss: 0.182001
# [221]	training's binary_logloss: 0.181921
# [222]	training's binary_logloss: 0.18178
# [223]	training's binary_logloss: 0.181679
# [224]	training's binary_logloss: 0.181535
# [225]	training's binary_logloss: 0.18134
# [226]	training's binary_logloss: 0.18111
# [227]	training's binary_logloss: 0.180958
# [228]	training's binary_logloss: 0.180808
# [229]	training's binary_logloss: 0.180611
# [230]	training's binary_logloss: 0.180445
# [231]	training's binary_logloss: 0.180163
# [232]	training's binary_logloss: 0.179978
# [233]	training's binary_logloss: 0.179833
# [234]	training's binary_logloss: 0.1796
# [235]	training's binary_logloss: 0.179206
# [236]	training's binary_logloss: 0.178896
# [237]	training's binary_logloss: 0.178723
# [238]	training's binary_logloss: 0.17858
# [239]	training's binary_logloss: 0.178352
# [240]	training's binary_logloss: 0.178114
# [241]	training's binary_logloss: 0.178005
# [242]	training's binary_logloss: 0.177873
# [243]	training's binary_logloss: 0.177618
# [244]	training's binary_logloss: 0.177247
# [245]	training's binary_logloss: 0.177012
# [246]	training's binary_logloss: 0.176772
# [247]	training's binary_logloss: 0.176648
# [248]	training's binary_logloss: 0.176302
# [249]	training's binary_logloss: 0.17612
# [250]	training's binary_logloss: 0.175871
# [251]	training's binary_logloss: 0.175771
# [252]	training's binary_logloss: 0.17545
# [253]	training's binary_logloss: 0.175201
# [254]	training's binary_logloss: 0.17495
# [255]	training's binary_logloss: 0.17472
# [256]	training's binary_logloss: 0.174258
# [257]	training's binary_logloss: 0.173996
# [258]	training's binary_logloss: 0.173616
# [259]	training's binary_logloss: 0.173346
# [260]	training's binary_logloss: 0.173176
# [261]	training's binary_logloss: 0.173031
# [262]	training's binary_logloss: 0.172905
# [263]	training's binary_logloss: 0.172592
# [264]	training's binary_logloss: 0.172209
# [265]	training's binary_logloss: 0.171862
# [266]	training's binary_logloss: 0.171726
# [267]	training's binary_logloss: 0.171429
# [268]	training's binary_logloss: 0.171217
# [269]	training's binary_logloss: 0.17107
# [270]	training's binary_logloss: 0.17089
# [271]	training's binary_logloss: 0.17069
# [272]	training's binary_logloss: 0.170515
# [273]	training's binary_logloss: 0.170436
# [274]	training's binary_logloss: 0.170306
# [275]	training's binary_logloss: 0.170151
# [276]	training's binary_logloss: 0.169862
# [277]	training's binary_logloss: 0.169633
# [278]	training's binary_logloss: 0.169484
# [279]	training's binary_logloss: 0.169424
# [280]	training's binary_logloss: 0.169279
# [281]	training's binary_logloss: 0.169181
# [282]	training's binary_logloss: 0.168965
# [283]	training's binary_logloss: 0.168837
# [284]	training's binary_logloss: 0.168615
# [285]	training's binary_logloss: 0.168435
# [286]	training's binary_logloss: 0.168278
# [287]	training's binary_logloss: 0.167969
# [288]	training's binary_logloss: 0.167741
# [289]	training's binary_logloss: 0.167547
# [290]	training's binary_logloss: 0.167426
# [291]	training's binary_logloss: 0.167164
# [292]	training's binary_logloss: 0.167004
# [293]	training's binary_logloss: 0.16681
# [294]	training's binary_logloss: 0.1666
# [295]	training's binary_logloss: 0.166376
# [296]	training's binary_logloss: 0.166174
# [297]	training's binary_logloss: 0.16606
# [298]	training's binary_logloss: 0.165979
# [299]	training's binary_logloss: 0.165866
# [300]	training's binary_logloss: 0.165642
# [301]	training's binary_logloss: 0.165478
# [302]	training's binary_logloss: 0.165352
# [303]	training's binary_logloss: 0.165179
# [304]	training's binary_logloss: 0.165034
# [305]	training's binary_logloss: 0.164812
# [306]	training's binary_logloss: 0.164496
# [307]	training's binary_logloss: 0.164292
# [308]	training's binary_logloss: 0.164183
# [309]	training's binary_logloss: 0.163979
# [310]	training's binary_logloss: 0.163785
# [311]	training's binary_logloss: 0.163621
# [312]	training's binary_logloss: 0.163385
# [313]	training's binary_logloss: 0.163281
# [314]	training's binary_logloss: 0.163114
# [315]	training's binary_logloss: 0.162929
# [316]	training's binary_logloss: 0.162772
# [317]	training's binary_logloss: 0.162664
# [318]	training's binary_logloss: 0.162515
# [319]	training's binary_logloss: 0.162287
# [320]	training's binary_logloss: 0.162154
# [321]	training's binary_logloss: 0.161988
# [322]	training's binary_logloss: 0.161795
# [323]	training's binary_logloss: 0.161566
# [324]	training's binary_logloss: 0.161377
# [325]	training's binary_logloss: 0.161267
# [326]	training's binary_logloss: 0.16105
# [327]	training's binary_logloss: 0.160928
# [328]	training's binary_logloss: 0.160811
# [329]	training's binary_logloss: 0.16064
# [330]	training's binary_logloss: 0.160394
# [331]	training's binary_logloss: 0.160311
# [332]	training's binary_logloss: 0.160216
# [333]	training's binary_logloss: 0.160066
# [334]	training's binary_logloss: 0.159966
# [335]	training's binary_logloss: 0.159817
# [336]	training's binary_logloss: 0.159501
# [337]	training's binary_logloss: 0.159335
# [338]	training's binary_logloss: 0.159197
# [339]	training's binary_logloss: 0.159009
# [340]	training's binary_logloss: 0.158859
# [341]	training's binary_logloss: 0.158739
# [342]	training's binary_logloss: 0.158617
# [343]	training's binary_logloss: 0.158478
# [344]	training's binary_logloss: 0.158418
# [345]	training's binary_logloss: 0.158162
# [346]	training's binary_logloss: 0.157948
# [347]	training's binary_logloss: 0.157778
# [348]	training's binary_logloss: 0.157645
# [349]	training's binary_logloss: 0.157314
# [350]	training's binary_logloss: 0.15716
# [351]	training's binary_logloss: 0.156925
# [352]	training's binary_logloss: 0.156759
# [353]	training's binary_logloss: 0.156566
# [354]	training's binary_logloss: 0.156392
# [355]	training's binary_logloss: 0.156228
# [356]	training's binary_logloss: 0.15606
# [357]	training's binary_logloss: 0.155842
# [358]	training's binary_logloss: 0.155687
# [359]	training's binary_logloss: 0.155609
# [360]	training's binary_logloss: 0.155488
# [361]	training's binary_logloss: 0.15521
# [362]	training's binary_logloss: 0.155053
# [363]	training's binary_logloss: 0.154936
# [364]	training's binary_logloss: 0.15485
# [365]	training's binary_logloss: 0.154687
# [366]	training's binary_logloss: 0.15458
# [367]	training's binary_logloss: 0.154349
# [368]	training's binary_logloss: 0.154238
# [369]	training's binary_logloss: 0.154067
# [370]	training's binary_logloss: 0.15385
# [371]	training's binary_logloss: 0.153739
# [372]	training's binary_logloss: 0.153618
# [373]	training's binary_logloss: 0.153408
# [374]	training's binary_logloss: 0.153298
# [375]	training's binary_logloss: 0.153136
# [376]	training's binary_logloss: 0.153024
# [377]	training's binary_logloss: 0.152783
# [378]	training's binary_logloss: 0.152545
# [379]	training's binary_logloss: 0.152415
# [380]	training's binary_logloss: 0.152173
# [381]	training's binary_logloss: 0.151984
# [382]	training's binary_logloss: 0.15187
# [383]	training's binary_logloss: 0.151667
# [384]	training's binary_logloss: 0.151558
# [385]	training's binary_logloss: 0.15142
# [386]	training's binary_logloss: 0.151247
# [387]	training's binary_logloss: 0.151133
# [388]	training's binary_logloss: 0.151028
# [389]	training's binary_logloss: 0.150914
# [390]	training's binary_logloss: 0.150786
# [391]	training's binary_logloss: 0.150657
# [392]	training's binary_logloss: 0.150521
# [393]	training's binary_logloss: 0.150413
# [394]	training's binary_logloss: 0.150239
# [395]	training's binary_logloss: 0.150112
# [396]	training's binary_logloss: 0.149851
# [397]	training's binary_logloss: 0.149667
# [398]	training's binary_logloss: 0.149552
# [399]	training's binary_logloss: 0.149443
# [400]	training's binary_logloss: 0.149311
# Did not meet early stopping. Best iteration is:
# [400]	training's binary_logloss: 0.149311

# %%
preds2 = lgbm_wrapper.predict(x_test)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score
from sklearn.metrics import f1_score, confusion_matrix, precision_recall_curve, roc_curve
from sklearn.preprocessing import StandardScaler, Binarizer
from sklearn.linear_model import LogisticRegression


def get_clf_eval(y_test, y_pred):
    confusion = confusion_matrix(y_test, y_pred)
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    F1 = f1_score(y_test, y_pred)
    AUC = roc_auc_score(y_test, y_pred)
    
    print('오차행렬:\n', confusion)
    print('\n정확도: {:.4f}'.format(accuracy))
    print('정밀도: {:.4f}'.format(precision))
    print('재현율: {:.4f}'.format(recall))
    print('F1: {:.4f}'.format(F1))
    print('AUC: {:.4f}'.format(AUC))

# %%
get_clf_eval(y_valid, preds)
# Out:
# 오차행렬:
#  [[3836  112]
#  [ 195 1066]]
#
# 정확도: 0.9411
# 정밀도: 0.9049
# 재현율: 0.8454
# F1: 0.8741
# AUC: 0.9085

# %%
sample_submission['prediction'] = preds2
sample_submission.to_csv('submission.csv', index=False)

# 0.84

# %% [markdown]
# # https://www.kaggle.com/mlisovyi/lightgbm-hyperparameter-optimisation-lb-0-761

# %% [markdown]
# ### Set up HyperParameter search

# %%
def learning_rate_010_decay_power_099(current_iter):
    base_learning_rate = 0.1
    lr = base_learning_rate  * np.power(.99, current_iter)
    return lr if lr > 1e-3 else 1e-3

def learning_rate_010_decay_power_0995(current_iter):
    base_learning_rate = 0.1
    lr = base_learning_rate  * np.power(.995, current_iter)
    return lr if lr > 1e-3 else 1e-3

def learning_rate_005_decay_power_099(current_iter):
    base_learning_rate = 0.05
    lr = base_learning_rate  * np.power(.99, current_iter)
    return lr if lr > 1e-3 else 1e-3

# %%
import lightgbm as lgb
fit_params={"early_stopping_rounds":30, 
            "eval_metric" : 'auc', 
            "eval_set" : [(tmp_x_valid, y_valid)],
            'eval_names': ['valid'],
            #'callbacks': [lgb.reset_parameter(learning_rate=learning_rate_010_decay_power_099)],
            'verbose': 100,
            'categorical_feature': 'auto'}

# %%
from scipy.stats import randint as sp_randint
from scipy.stats import uniform as sp_uniform
param_test ={'num_leaves': sp_randint(6, 50), 
             'min_child_samples': sp_randint(100, 500), 
             'min_child_weight': [1e-5, 1e-3, 1e-2, 1e-1, 1, 1e1, 1e2, 1e3, 1e4],
             'subsample': sp_uniform(loc=0.2, scale=0.8), 
             'colsample_bytree': sp_uniform(loc=0.4, scale=0.6),
             'reg_alpha': [0, 1e-1, 1, 2, 5, 7, 10, 50, 100],
             'reg_lambda': [0, 1e-1, 1, 5, 10, 20, 50, 100]}

# %%
#This parameter defines the number of HP points to be tested
n_HP_points_to_test = 100

import lightgbm as lgb
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

#n_estimators is set to a "large value". The actual number of trees build will depend on early stopping and 5000 define only the absolute maximum
clf = lgb.LGBMClassifier(max_depth=-1, random_state=314, silent=True, metric='None', n_jobs=4, n_estimators=5000)
gs = RandomizedSearchCV(
    estimator=clf, param_distributions=param_test, 
    n_iter=n_HP_points_to_test,
    scoring='f1_macro',
    cv=3,
    refit=True,
    random_state=314,
    verbose=True)

# %%
gs.fit(tmp_x_train, y_train, **fit_params)
print('Best score reached: {} with params: {} '.format(gs.best_score_, gs.best_params_))
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# Training until validation scores don't improve for 30 rounds
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [100]	valid's auc: 0.917212
# [200]	valid's auc: 0.91772
# [300]	valid's auc: 0.918712
# [400]	valid's auc: 0.919205
# [500]	valid's auc: 0.919375
# Early stopping, best iteration is:
# [476]	valid's auc: 0.919436
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.917797
# [200]	valid's auc: 0.918585
# [300]	valid's auc: 0.919015
# Early stopping, best iteration is:
# [360]	valid's auc: 0.9191
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.916435
# [200]	valid's auc: 0.917749
# [300]	valid's auc: 0.918376
# [400]	valid's auc: 0.918694
# [500]	valid's auc: 0.918879
# Early stopping, best iteration is:
# [545]	valid's auc: 0.91899
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.916644
# [200]	valid's auc: 0.917889
# [300]	valid's auc: 0.918317
# [400]	valid's auc: 0.918577
# [500]	valid's auc: 0.918737
# [600]	valid's auc: 0.918832
# [700]	valid's auc: 0.918907
# [800]	valid's auc: 0.918932
# [900]	valid's auc: 0.918941
# Early stopping, best iteration is:
# [969]	valid's auc: 0.918963
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.916768
# [200]	valid's auc: 0.917905
# [300]	valid's auc: 0.918529
# [400]	valid's auc: 0.918834
# [500]	valid's auc: 0.919007
# [600]	valid's auc: 0.919128
# [700]	valid's auc: 0.919208
# [800]	valid's auc: 0.919265
# [900]	valid's auc: 0.919304
# [1000]	valid's auc: 0.919334
# [1100]	valid's auc: 0.919363
# [1200]	valid's auc: 0.919383
# [1300]	valid's auc: 0.919399
# [1400]	valid's auc: 0.919412
# Early stopping, best iteration is:
# [1410]	valid's auc: 0.919416
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.915723
# [200]	valid's auc: 0.9176
# [300]	valid's auc: 0.918233
# [400]	valid's auc: 0.918607
# [500]	valid's auc: 0.918805
# [600]	valid's auc: 0.918886
# [700]	valid's auc: 0.918925
# [800]	valid's auc: 0.918989
# [900]	valid's auc: 0.919047
# [1000]	valid's auc: 0.919093
# [1100]	valid's auc: 0.91913
# [1200]	valid's auc: 0.919161
# [1300]	valid's auc: 0.919183
# [1400]	valid's auc: 0.919204
# [1500]	valid's auc: 0.919219
# [1600]	valid's auc: 0.919234
# [1700]	valid's auc: 0.919244
# [1800]	valid's auc: 0.919252
# [1900]	valid's auc: 0.919258
# Early stopping, best iteration is:
# [1881]	valid's auc: 0.919258
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [8]	valid's auc: 0.832675
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [8]	valid's auc: 0.832675
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [8]	valid's auc: 0.832675
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.904749
# Early stopping, best iteration is:
# [139]	valid's auc: 0.904754
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.903761
# Early stopping, best iteration is:
# [118]	valid's auc: 0.903761
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.90409
# Early stopping, best iteration is:
# [129]	valid's auc: 0.904091
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.919761
# [200]	valid's auc: 0.922549
# [300]	valid's auc: 0.92297
# Early stopping, best iteration is:
# [322]	valid's auc: 0.923098
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.920763
# [200]	valid's auc: 0.922771
# [300]	valid's auc: 0.923552
# Early stopping, best iteration is:
# [365]	valid's auc: 0.923686
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.920786
# [200]	valid's auc: 0.923938
# [300]	valid's auc: 0.924529
# [400]	valid's auc: 0.92493
# [500]	valid's auc: 0.924933
# Early stopping, best iteration is:
# [471]	valid's auc: 0.925059
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.916506
# [200]	valid's auc: 0.917236
# [300]	valid's auc: 0.917789
# [400]	valid's auc: 0.918378
# [500]	valid's auc: 0.918706
# Early stopping, best iteration is:
# [487]	valid's auc: 0.918764
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.918096
# [200]	valid's auc: 0.918616
# Early stopping, best iteration is:
# [182]	valid's auc: 0.918765
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.917451
# [200]	valid's auc: 0.91825
# [300]	valid's auc: 0.918966
# [400]	valid's auc: 0.919374
# Early stopping, best iteration is:
# [453]	valid's auc: 0.919519
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.916655
# [200]	valid's auc: 0.917424
# Early stopping, best iteration is:
# [181]	valid's auc: 0.917508
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.917401
# Early stopping, best iteration is:
# [168]	valid's auc: 0.918069
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.916735
# [200]	valid's auc: 0.917577
# [300]	valid's auc: 0.91821
# [400]	valid's auc: 0.918568
# [500]	valid's auc: 0.918876
# [600]	valid's auc: 0.919084
# [700]	valid's auc: 0.919417
# Early stopping, best iteration is:
# [703]	valid's auc: 0.919421
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.918732
# [200]	valid's auc: 0.921402
# [300]	valid's auc: 0.922523
# [400]	valid's auc: 0.922977
# [500]	valid's auc: 0.923153
# Early stopping, best iteration is:
# [476]	valid's auc: 0.9232
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.919218
# [200]	valid's auc: 0.92105
# [300]	valid's auc: 0.921813
# Early stopping, best iteration is:
# [274]	valid's auc: 0.921844
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.919218
# [200]	valid's auc: 0.922094
# [300]	valid's auc: 0.923128
# [400]	valid's auc: 0.923625
# [500]	valid's auc: 0.923993
# [600]	valid's auc: 0.924262
# Early stopping, best iteration is:
# [654]	valid's auc: 0.924383
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.920964
# [200]	valid's auc: 0.922199
# [300]	valid's auc: 0.922557
# [400]	valid's auc: 0.92293
# [500]	valid's auc: 0.923221
# [600]	valid's auc: 0.923348
# [700]	valid's auc: 0.923517
# Early stopping, best iteration is:
# [699]	valid's auc: 0.923538
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.921388
# [200]	valid's auc: 0.922519
# [300]	valid's auc: 0.922925
# Early stopping, best iteration is:
# [270]	valid's auc: 0.922982
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.921144
# [200]	valid's auc: 0.922701
# [300]	valid's auc: 0.923268
# [400]	valid's auc: 0.923672
# [500]	valid's auc: 0.923983
# [600]	valid's auc: 0.924232
# [700]	valid's auc: 0.924396
# [800]	valid's auc: 0.924532
# [900]	valid's auc: 0.924602
# [1000]	valid's auc: 0.924645
# Early stopping, best iteration is:
# [1017]	valid's auc: 0.924651
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.915839
# [200]	valid's auc: 0.916856
# [300]	valid's auc: 0.917306
# [400]	valid's auc: 0.917652
# [500]	valid's auc: 0.917907
# [600]	valid's auc: 0.918136
# [700]	valid's auc: 0.918343
# [800]	valid's auc: 0.918462
# [900]	valid's auc: 0.918614
# [1000]	valid's auc: 0.91873
# [1100]	valid's auc: 0.918821
# [1200]	valid's auc: 0.918894
# [1300]	valid's auc: 0.918963
# [1400]	valid's auc: 0.919023
# [1500]	valid's auc: 0.91908
# [1600]	valid's auc: 0.919145
# [1700]	valid's auc: 0.919192
# [1800]	valid's auc: 0.919253
# [1900]	valid's auc: 0.919297
# [2000]	valid's auc: 0.919342
# [2100]	valid's auc: 0.919379
# [2200]	valid's auc: 0.919408
# [2300]	valid's auc: 0.919442
# [2400]	valid's auc: 0.919473
# [2500]	valid's auc: 0.9195
# [2600]	valid's auc: 0.919538
# [2700]	valid's auc: 0.919568
# [2800]	valid's auc: 0.919608
# [2900]	valid's auc: 0.919644
# [3000]	valid's auc: 0.919681
# [3100]	valid's auc: 0.919713
# Early stopping, best iteration is:
# [3151]	valid's auc: 0.919722
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.916452
# [200]	valid's auc: 0.917287
# [300]	valid's auc: 0.917695
# [400]	valid's auc: 0.918039
# [500]	valid's auc: 0.918326
# [600]	valid's auc: 0.918543
# [700]	valid's auc: 0.918782
# [800]	valid's auc: 0.918917
# [900]	valid's auc: 0.919057
# [1000]	valid's auc: 0.919179
# [1100]	valid's auc: 0.919273
# [1200]	valid's auc: 0.919355
# [1300]	valid's auc: 0.919422
# [1400]	valid's auc: 0.919487
# [1500]	valid's auc: 0.919527
# [1600]	valid's auc: 0.919579
# [1700]	valid's auc: 0.919611
# [1800]	valid's auc: 0.919644
# [1900]	valid's auc: 0.919672
# [2000]	valid's auc: 0.919698
# [2100]	valid's auc: 0.919712
# [2200]	valid's auc: 0.919728
# Early stopping, best iteration is:
# [2183]	valid's auc: 0.919732
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.915879
# [200]	valid's auc: 0.916888
# [300]	valid's auc: 0.917382
# [400]	valid's auc: 0.917709
# [500]	valid's auc: 0.917999
# [600]	valid's auc: 0.918209
# [700]	valid's auc: 0.918444
# [800]	valid's auc: 0.918581
# [900]	valid's auc: 0.918723
# [1000]	valid's auc: 0.918825
# [1100]	valid's auc: 0.91892
# [1200]	valid's auc: 0.918992
# [1300]	valid's auc: 0.919046
# [1400]	valid's auc: 0.9191
# [1500]	valid's auc: 0.919147
# [1600]	valid's auc: 0.9192
# [1700]	valid's auc: 0.919237
# [1800]	valid's auc: 0.919281
# [1900]	valid's auc: 0.919312
# [2000]	valid's auc: 0.919339
# [2100]	valid's auc: 0.919366
# [2200]	valid's auc: 0.919382
# [2300]	valid's auc: 0.919399
# [2400]	valid's auc: 0.919408
# [2500]	valid's auc: 0.919416
# [2600]	valid's auc: 0.919431
# Early stopping, best iteration is:
# [2584]	valid's auc: 0.919431
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.916589
# [200]	valid's auc: 0.917349
# [300]	valid's auc: 0.917613
# [400]	valid's auc: 0.917995
# [500]	valid's auc: 0.918332
# [600]	valid's auc: 0.918631
# [700]	valid's auc: 0.918854
# [800]	valid's auc: 0.919065
# [900]	valid's auc: 0.919248
# [1000]	valid's auc: 0.919413
# [1100]	valid's auc: 0.91952
# [1200]	valid's auc: 0.919637
# [1300]	valid's auc: 0.91975
# [1400]	valid's auc: 0.919855
# [1500]	valid's auc: 0.919986
# [1600]	valid's auc: 0.920098
# [1700]	valid's auc: 0.920175
# [1800]	valid's auc: 0.920238
# [1900]	valid's auc: 0.920314
# [2000]	valid's auc: 0.920368
# [2100]	valid's auc: 0.920424
# [2200]	valid's auc: 0.920481
# [2300]	valid's auc: 0.920515
# [2400]	valid's auc: 0.920561
# [2500]	valid's auc: 0.920599
# [2600]	valid's auc: 0.920635
# [2700]	valid's auc: 0.92067
# [2800]	valid's auc: 0.920706
# [2900]	valid's auc: 0.920735
# [3000]	valid's auc: 0.920751
# [3100]	valid's auc: 0.920773
# Early stopping, best iteration is:
# [3082]	valid's auc: 0.920777
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.917033
# [200]	valid's auc: 0.917707
# [300]	valid's auc: 0.918135
# [400]	valid's auc: 0.918482
# [500]	valid's auc: 0.918729
# [600]	valid's auc: 0.91894
# [700]	valid's auc: 0.919104
# [800]	valid's auc: 0.919292
# [900]	valid's auc: 0.919402
# [1000]	valid's auc: 0.919515
# [1100]	valid's auc: 0.919613
# [1200]	valid's auc: 0.919707
# [1300]	valid's auc: 0.919776
# [1400]	valid's auc: 0.919848
# [1500]	valid's auc: 0.919911
# [1600]	valid's auc: 0.919947
# [1700]	valid's auc: 0.920005
# [1800]	valid's auc: 0.92005
# [1900]	valid's auc: 0.920089
# [2000]	valid's auc: 0.920113
# [2100]	valid's auc: 0.920134
# [2200]	valid's auc: 0.92015
# [2300]	valid's auc: 0.920162
# [2400]	valid's auc: 0.920173
# [2500]	valid's auc: 0.92018
# [2600]	valid's auc: 0.920189
# [2700]	valid's auc: 0.920198
# [2800]	valid's auc: 0.920209
# [2900]	valid's auc: 0.920215
# [3000]	valid's auc: 0.920222
# [3100]	valid's auc: 0.920231
# [3200]	valid's auc: 0.920235
# [3300]	valid's auc: 0.920244
# [3400]	valid's auc: 0.920249
# [3500]	valid's auc: 0.920253
# Early stopping, best iteration is:
# [3533]	valid's auc: 0.920254
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.916905
# [200]	valid's auc: 0.91778
# [300]	valid's auc: 0.918218
# [400]	valid's auc: 0.918624
# [500]	valid's auc: 0.918949
# [600]	valid's auc: 0.919189
# [700]	valid's auc: 0.919392
# [800]	valid's auc: 0.919555
# [900]	valid's auc: 0.919696
# [1000]	valid's auc: 0.919836
# [1100]	valid's auc: 0.919932
# [1200]	valid's auc: 0.920031
# [1300]	valid's auc: 0.920118
# [1400]	valid's auc: 0.92022
# [1500]	valid's auc: 0.920292
# [1600]	valid's auc: 0.920348
# [1700]	valid's auc: 0.920405
# [1800]	valid's auc: 0.920444
# [1900]	valid's auc: 0.920504
# [2000]	valid's auc: 0.920532
# [2100]	valid's auc: 0.920557
# [2200]	valid's auc: 0.920589
# [2300]	valid's auc: 0.920625
# [2400]	valid's auc: 0.920649
# [2500]	valid's auc: 0.920681
# [2600]	valid's auc: 0.920707
# [2700]	valid's auc: 0.92073
# [2800]	valid's auc: 0.920744
# Early stopping, best iteration is:
# [2777]	valid's auc: 0.920746
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.91696
# Early stopping, best iteration is:
# [169]	valid's auc: 0.917655
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.917153
# [200]	valid's auc: 0.917835
# [300]	valid's auc: 0.918271
# [400]	valid's auc: 0.918564
# [500]	valid's auc: 0.918773
# [600]	valid's auc: 0.918914
# [700]	valid's auc: 0.919069
# [800]	valid's auc: 0.919202
# Early stopping, best iteration is:
# [858]	valid's auc: 0.919286
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.916419
# [200]	valid's auc: 0.917323
# [300]	valid's auc: 0.917878
# [400]	valid's auc: 0.918231
# [500]	valid's auc: 0.918611
# [600]	valid's auc: 0.918882
# [700]	valid's auc: 0.919164
# [800]	valid's auc: 0.919449
# [900]	valid's auc: 0.919725
# [1000]	valid's auc: 0.919927
# [1100]	valid's auc: 0.92012
# [1200]	valid's auc: 0.920318
# [1300]	valid's auc: 0.920486
# [1400]	valid's auc: 0.920695
# [1500]	valid's auc: 0.920827
# [1600]	valid's auc: 0.920956
# [1700]	valid's auc: 0.921053
# [1800]	valid's auc: 0.921189
# [1900]	valid's auc: 0.921293
# [2000]	valid's auc: 0.92141
# [2100]	valid's auc: 0.921501
# [2200]	valid's auc: 0.921588
# [2300]	valid's auc: 0.921653
# [2400]	valid's auc: 0.921754
# [2500]	valid's auc: 0.921796
# [2600]	valid's auc: 0.921871
# [2700]	valid's auc: 0.921908
# [2800]	valid's auc: 0.92196
# [2900]	valid's auc: 0.922018
# Early stopping, best iteration is:
# [2903]	valid's auc: 0.922025
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [2]	valid's auc: 0.832675
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [2]	valid's auc: 0.832675
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [2]	valid's auc: 0.832675
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.914184
# [200]	valid's auc: 0.915221
# [300]	valid's auc: 0.91566
# [400]	valid's auc: 0.916195
# [500]	valid's auc: 0.916503
# Early stopping, best iteration is:
# [517]	valid's auc: 0.916562
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.91376
# [200]	valid's auc: 0.914954
# [300]	valid's auc: 0.915238
# [400]	valid's auc: 0.91575
# [500]	valid's auc: 0.916297
# [600]	valid's auc: 0.916484
# Early stopping, best iteration is:
# [627]	valid's auc: 0.916546
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.91372
# [200]	valid's auc: 0.915335
# [300]	valid's auc: 0.915799
# [400]	valid's auc: 0.916711
# [500]	valid's auc: 0.917064
# [600]	valid's auc: 0.917203
# Early stopping, best iteration is:
# [610]	valid's auc: 0.917214
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.909732
# [200]	valid's auc: 0.911299
# Early stopping, best iteration is:
# [224]	valid's auc: 0.91163
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.910664
# [200]	valid's auc: 0.911808
# [300]	valid's auc: 0.912425
# Early stopping, best iteration is:
# [360]	valid's auc: 0.912768
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.909743
# [200]	valid's auc: 0.910833
# Early stopping, best iteration is:
# [223]	valid's auc: 0.911046
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.919075
# [200]	valid's auc: 0.92084
# [300]	valid's auc: 0.921964
# Early stopping, best iteration is:
# [368]	valid's auc: 0.922433
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.919663
# [200]	valid's auc: 0.921016
# [300]	valid's auc: 0.922134
# [400]	valid's auc: 0.922825
# [500]	valid's auc: 0.923115
# Early stopping, best iteration is:
# [552]	valid's auc: 0.923201
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.919782
# [200]	valid's auc: 0.922051
# [300]	valid's auc: 0.923395
# [400]	valid's auc: 0.924271
# [500]	valid's auc: 0.924517
# Early stopping, best iteration is:
# [490]	valid's auc: 0.924563
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.90788
# Early stopping, best iteration is:
# [134]	valid's auc: 0.907976
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.908083
# Early stopping, best iteration is:
# [157]	valid's auc: 0.908185
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.907303
# Early stopping, best iteration is:
# [131]	valid's auc: 0.907513
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.923502
# Early stopping, best iteration is:
# [99]	valid's auc: 0.923588
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.922546
# Early stopping, best iteration is:
# [120]	valid's auc: 0.922961
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.923954
# Early stopping, best iteration is:
# [91]	valid's auc: 0.924065
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.905566
# Early stopping, best iteration is:
# [84]	valid's auc: 0.905566
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.905477
# Early stopping, best iteration is:
# [84]	valid's auc: 0.905477
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.905505
# Early stopping, best iteration is:
# [135]	valid's auc: 0.905518
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.917533
# [200]	valid's auc: 0.919095
# [300]	valid's auc: 0.919604
# [400]	valid's auc: 0.92037
# [500]	valid's auc: 0.920449
# Early stopping, best iteration is:
# [523]	valid's auc: 0.920573
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.918344
# [200]	valid's auc: 0.919731
# [300]	valid's auc: 0.920517
# [400]	valid's auc: 0.920797
# Early stopping, best iteration is:
# [429]	valid's auc: 0.920941
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.918139
# [200]	valid's auc: 0.919782
# [300]	valid's auc: 0.920514
# [400]	valid's auc: 0.921019
# [500]	valid's auc: 0.921222
# [600]	valid's auc: 0.921473
# Early stopping, best iteration is:
# [586]	valid's auc: 0.92155
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.904023
# Early stopping, best iteration is:
# [96]	valid's auc: 0.904023
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.903821
# Early stopping, best iteration is:
# [98]	valid's auc: 0.903822
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.902948
# Early stopping, best iteration is:
# [128]	valid's auc: 0.902958
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.916401
# [200]	valid's auc: 0.918372
# [300]	valid's auc: 0.91916
# [400]	valid's auc: 0.919748
# [500]	valid's auc: 0.920021
# [600]	valid's auc: 0.920267
# [700]	valid's auc: 0.920501
# [800]	valid's auc: 0.920689
# [900]	valid's auc: 0.920818
# [1000]	valid's auc: 0.920949
# [1100]	valid's auc: 0.921123
# Early stopping, best iteration is:
# [1158]	valid's auc: 0.921301
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.917224
# [200]	valid's auc: 0.918969
# [300]	valid's auc: 0.91952
# [400]	valid's auc: 0.920026
# [500]	valid's auc: 0.920349
# [600]	valid's auc: 0.920562
# [700]	valid's auc: 0.920853
# [800]	valid's auc: 0.921044
# [900]	valid's auc: 0.921201
# [1000]	valid's auc: 0.92132
# [1100]	valid's auc: 0.921431
# [1200]	valid's auc: 0.921608
# Early stopping, best iteration is:
# [1266]	valid's auc: 0.921701
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.916622
# [200]	valid's auc: 0.91871
# [300]	valid's auc: 0.919471
# [400]	valid's auc: 0.920137
# [500]	valid's auc: 0.920537
# [600]	valid's auc: 0.920766
# [700]	valid's auc: 0.921155
# [800]	valid's auc: 0.921445
# [900]	valid's auc: 0.921659
# [1000]	valid's auc: 0.921851
# [1100]	valid's auc: 0.922025
# [1200]	valid's auc: 0.922192
# [1300]	valid's auc: 0.922321
# [1400]	valid's auc: 0.922449
# [1500]	valid's auc: 0.922566
# [1600]	valid's auc: 0.922651
# [1700]	valid's auc: 0.92274
# Early stopping, best iteration is:
# [1754]	valid's auc: 0.922802
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.918333
# [200]	valid's auc: 0.919853
# [300]	valid's auc: 0.920538
# [400]	valid's auc: 0.921003
# [500]	valid's auc: 0.921459
# [600]	valid's auc: 0.921694
# [700]	valid's auc: 0.921959
# Early stopping, best iteration is:
# [733]	valid's auc: 0.922022
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.918293
# [200]	valid's auc: 0.919347
# [300]	valid's auc: 0.919878
# Early stopping, best iteration is:
# [283]	valid's auc: 0.919935
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.91852
# [200]	valid's auc: 0.919673
# [300]	valid's auc: 0.920373
# [400]	valid's auc: 0.920771
# [500]	valid's auc: 0.921059
# [600]	valid's auc: 0.921262
# [700]	valid's auc: 0.921519
# [800]	valid's auc: 0.922232
# [900]	valid's auc: 0.922616
# [1000]	valid's auc: 0.922833
# [1100]	valid's auc: 0.923003
# [1200]	valid's auc: 0.923091
# [1300]	valid's auc: 0.923143
# Early stopping, best iteration is:
# [1348]	valid's auc: 0.923214
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.921207
# [200]	valid's auc: 0.922729
# [300]	valid's auc: 0.922921
# Early stopping, best iteration is:
# [276]	valid's auc: 0.922921
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.921956
# [200]	valid's auc: 0.923101
# [300]	valid's auc: 0.923535
# [400]	valid's auc: 0.923667
# [500]	valid's auc: 0.923714
# Early stopping, best iteration is:
# [513]	valid's auc: 0.923715
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.921357
# [200]	valid's auc: 0.922458
# Early stopping, best iteration is:
# [257]	valid's auc: 0.9227
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.918331
# [200]	valid's auc: 0.920015
# [300]	valid's auc: 0.920766
# [400]	valid's auc: 0.921106
# [500]	valid's auc: 0.921443
# [600]	valid's auc: 0.921669
# [700]	valid's auc: 0.921826
# [800]	valid's auc: 0.921939
# [900]	valid's auc: 0.922026
# [1000]	valid's auc: 0.922099
# Early stopping, best iteration is:
# [983]	valid's auc: 0.922099
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.919322
# [200]	valid's auc: 0.92046
# [300]	valid's auc: 0.920919
# [400]	valid's auc: 0.921307
# [500]	valid's auc: 0.921568
# [600]	valid's auc: 0.92174
# [700]	valid's auc: 0.921893
# [800]	valid's auc: 0.922023
# [900]	valid's auc: 0.922106
# [1000]	valid's auc: 0.92217
# [1100]	valid's auc: 0.922216
# [1200]	valid's auc: 0.922271
# [1300]	valid's auc: 0.922315
# [1400]	valid's auc: 0.922351
# Early stopping, best iteration is:
# [1375]	valid's auc: 0.922351
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.918254
# [200]	valid's auc: 0.919878
# [300]	valid's auc: 0.920461
# [400]	valid's auc: 0.920748
# [500]	valid's auc: 0.92103
# [600]	valid's auc: 0.921165
# [700]	valid's auc: 0.921294
# [800]	valid's auc: 0.921376
# [900]	valid's auc: 0.921458
# [1000]	valid's auc: 0.921517
# [1100]	valid's auc: 0.921577
# [1200]	valid's auc: 0.921632
# [1300]	valid's auc: 0.921674
# Early stopping, best iteration is:
# [1287]	valid's auc: 0.921675
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.914846
# [200]	valid's auc: 0.916563
# [300]	valid's auc: 0.916844
# [400]	valid's auc: 0.917151
# [500]	valid's auc: 0.91746
# [600]	valid's auc: 0.917661
# [700]	valid's auc: 0.917892
# [800]	valid's auc: 0.918019
# [900]	valid's auc: 0.918178
# [1000]	valid's auc: 0.918292
# [1100]	valid's auc: 0.918406
# [1200]	valid's auc: 0.91849
# [1300]	valid's auc: 0.918574
# [1400]	valid's auc: 0.918666
# [1500]	valid's auc: 0.918725
# [1600]	valid's auc: 0.918794
# [1700]	valid's auc: 0.918843
# [1800]	valid's auc: 0.918923
# [1900]	valid's auc: 0.918961
# [2000]	valid's auc: 0.919024
# [2100]	valid's auc: 0.919061
# [2200]	valid's auc: 0.919107
# [2300]	valid's auc: 0.919144
# [2400]	valid's auc: 0.919186
# [2500]	valid's auc: 0.919219
# [2600]	valid's auc: 0.919255
# [2700]	valid's auc: 0.919275
# [2800]	valid's auc: 0.919309
# [2900]	valid's auc: 0.919338
# [3000]	valid's auc: 0.919365
# [3100]	valid's auc: 0.919396
# [3200]	valid's auc: 0.919417
# [3300]	valid's auc: 0.919432
# [3400]	valid's auc: 0.919455
# [3500]	valid's auc: 0.919484
# Early stopping, best iteration is:
# [3567]	valid's auc: 0.919507
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.915434
# [200]	valid's auc: 0.917108
# [300]	valid's auc: 0.917432
# [400]	valid's auc: 0.917702
# [500]	valid's auc: 0.917993
# [600]	valid's auc: 0.918179
# [700]	valid's auc: 0.918383
# [800]	valid's auc: 0.918533
# [900]	valid's auc: 0.918697
# [1000]	valid's auc: 0.918821
# [1100]	valid's auc: 0.918927
# [1200]	valid's auc: 0.919021
# [1300]	valid's auc: 0.919106
# [1400]	valid's auc: 0.919179
# [1500]	valid's auc: 0.919244
# [1600]	valid's auc: 0.919322
# [1700]	valid's auc: 0.919377
# [1800]	valid's auc: 0.919432
# [1900]	valid's auc: 0.919475
# [2000]	valid's auc: 0.919516
# [2100]	valid's auc: 0.919555
# [2200]	valid's auc: 0.919602
# [2300]	valid's auc: 0.919636
# [2400]	valid's auc: 0.919672
# [2500]	valid's auc: 0.919697
# [2600]	valid's auc: 0.919722
# [2700]	valid's auc: 0.919749
# [2800]	valid's auc: 0.919779
# [2900]	valid's auc: 0.919798
# [3000]	valid's auc: 0.919814
# [3100]	valid's auc: 0.919836
# [3200]	valid's auc: 0.919851
# [3300]	valid's auc: 0.919863
# Early stopping, best iteration is:
# [3351]	valid's auc: 0.919867
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.914313
# [200]	valid's auc: 0.916032
# [300]	valid's auc: 0.916368
# [400]	valid's auc: 0.916667
# [500]	valid's auc: 0.916952
# [600]	valid's auc: 0.917169
# [700]	valid's auc: 0.917394
# [800]	valid's auc: 0.917546
# [900]	valid's auc: 0.917716
# [1000]	valid's auc: 0.91785
# [1100]	valid's auc: 0.917954
# [1200]	valid's auc: 0.91805
# [1300]	valid's auc: 0.918137
# [1400]	valid's auc: 0.918222
# [1500]	valid's auc: 0.918279
# [1600]	valid's auc: 0.918357
# [1700]	valid's auc: 0.918409
# [1800]	valid's auc: 0.918465
# [1900]	valid's auc: 0.918506
# [2000]	valid's auc: 0.918559
# [2100]	valid's auc: 0.918589
# [2200]	valid's auc: 0.918627
# [2300]	valid's auc: 0.918653
# [2400]	valid's auc: 0.91869
# [2500]	valid's auc: 0.918719
# [2600]	valid's auc: 0.91875
# [2700]	valid's auc: 0.918773
# [2800]	valid's auc: 0.918796
# [2900]	valid's auc: 0.918824
# [3000]	valid's auc: 0.918845
# [3100]	valid's auc: 0.918871
# [3200]	valid's auc: 0.918882
# [3300]	valid's auc: 0.918895
# [3400]	valid's auc: 0.91891
# [3500]	valid's auc: 0.918922
# [3600]	valid's auc: 0.918929
# [3700]	valid's auc: 0.918937
# [3800]	valid's auc: 0.918944
# Early stopping, best iteration is:
# [3812]	valid's auc: 0.918947
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.909974
# [200]	valid's auc: 0.911207
# [300]	valid's auc: 0.91123
# [400]	valid's auc: 0.911233
# Early stopping, best iteration is:
# [430]	valid's auc: 0.911234
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.910167
# [200]	valid's auc: 0.911439
# [300]	valid's auc: 0.911469
# [400]	valid's auc: 0.911472
# Early stopping, best iteration is:
# [414]	valid's auc: 0.911472
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.909545
# [200]	valid's auc: 0.910872
# [300]	valid's auc: 0.910932
# Early stopping, best iteration is:
# [280]	valid's auc: 0.910933
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.906691
# Early stopping, best iteration is:
# [71]	valid's auc: 0.906705
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [61]	valid's auc: 0.906672
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.906144
# Early stopping, best iteration is:
# [156]	valid's auc: 0.906146
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.91771
# Early stopping, best iteration is:
# [166]	valid's auc: 0.918184
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.917607
# [200]	valid's auc: 0.917983
# Early stopping, best iteration is:
# [221]	valid's auc: 0.918278
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.918144
# [200]	valid's auc: 0.918504
# Early stopping, best iteration is:
# [181]	valid's auc: 0.91855
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.917084
# [200]	valid's auc: 0.917945
# [300]	valid's auc: 0.918392
# Early stopping, best iteration is:
# [368]	valid's auc: 0.918516
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.917772
# [200]	valid's auc: 0.918541
# [300]	valid's auc: 0.918889
# [400]	valid's auc: 0.919126
# [500]	valid's auc: 0.919319
# [600]	valid's auc: 0.919467
# [700]	valid's auc: 0.919528
# Early stopping, best iteration is:
# [700]	valid's auc: 0.919528
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.917501
# [200]	valid's auc: 0.918561
# [300]	valid's auc: 0.918897
# [400]	valid's auc: 0.918959
# [500]	valid's auc: 0.918999
# Early stopping, best iteration is:
# [542]	valid's auc: 0.919007
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.908044
# [200]	valid's auc: 0.908117
# Early stopping, best iteration is:
# [180]	valid's auc: 0.908117
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.907748
# Early stopping, best iteration is:
# [161]	valid's auc: 0.907972
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.906812
# Early stopping, best iteration is:
# [116]	valid's auc: 0.907065
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.916346
# [200]	valid's auc: 0.917049
# [300]	valid's auc: 0.917626
# [400]	valid's auc: 0.917998
# [500]	valid's auc: 0.918232
# [600]	valid's auc: 0.918459
# [700]	valid's auc: 0.91861
# [800]	valid's auc: 0.918725
# [900]	valid's auc: 0.918819
# [1000]	valid's auc: 0.918904
# [1100]	valid's auc: 0.918963
# [1200]	valid's auc: 0.919056
# [1300]	valid's auc: 0.919088
# [1400]	valid's auc: 0.91911
# [1500]	valid's auc: 0.919134
# [1600]	valid's auc: 0.919152
# [1700]	valid's auc: 0.919164
# [1800]	valid's auc: 0.919176
# Early stopping, best iteration is:
# [1866]	valid's auc: 0.919185
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.916525
# [200]	valid's auc: 0.917318
# [300]	valid's auc: 0.917836
# [400]	valid's auc: 0.918163
# [500]	valid's auc: 0.918402
# [600]	valid's auc: 0.918572
# [700]	valid's auc: 0.918692
# [800]	valid's auc: 0.918801
# [900]	valid's auc: 0.918899
# [1000]	valid's auc: 0.918981
# [1100]	valid's auc: 0.919046
# [1200]	valid's auc: 0.919108
# [1300]	valid's auc: 0.919128
# [1400]	valid's auc: 0.919152
# [1500]	valid's auc: 0.919168
# [1600]	valid's auc: 0.919188
# Early stopping, best iteration is:
# [1646]	valid's auc: 0.919194
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.9167
# [200]	valid's auc: 0.917574
# [300]	valid's auc: 0.918069
# [400]	valid's auc: 0.918331
# [500]	valid's auc: 0.918544
# [600]	valid's auc: 0.918702
# [700]	valid's auc: 0.918856
# [800]	valid's auc: 0.918942
# [900]	valid's auc: 0.919062
# [1000]	valid's auc: 0.91914
# [1100]	valid's auc: 0.919187
# [1200]	valid's auc: 0.919247
# [1300]	valid's auc: 0.919305
# [1400]	valid's auc: 0.919364
# [1500]	valid's auc: 0.919404
# [1600]	valid's auc: 0.919412
# Early stopping, best iteration is:
# [1618]	valid's auc: 0.919412
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.91924
# [200]	valid's auc: 0.921207
# [300]	valid's auc: 0.921745
# Early stopping, best iteration is:
# [272]	valid's auc: 0.921874
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.920048
# [200]	valid's auc: 0.921736
# [300]	valid's auc: 0.921693
# Early stopping, best iteration is:
# [270]	valid's auc: 0.922009
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.920084
# [200]	valid's auc: 0.922301
# [300]	valid's auc: 0.922885
# [400]	valid's auc: 0.923094
# Early stopping, best iteration is:
# [422]	valid's auc: 0.923219
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [8]	valid's auc: 0.832675
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [8]	valid's auc: 0.832675
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [8]	valid's auc: 0.832675
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.914513
# [200]	valid's auc: 0.915255
# Early stopping, best iteration is:
# [181]	valid's auc: 0.915327
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.914379
# Early stopping, best iteration is:
# [144]	valid's auc: 0.91513
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.914224
# [200]	valid's auc: 0.91517
# [300]	valid's auc: 0.916058
# [400]	valid's auc: 0.916635
# [500]	valid's auc: 0.916889
# [600]	valid's auc: 0.917001
# Early stopping, best iteration is:
# [646]	valid's auc: 0.917052
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.916352
# [200]	valid's auc: 0.917173
# [300]	valid's auc: 0.917459
# [400]	valid's auc: 0.91762
# [500]	valid's auc: 0.917769
# [600]	valid's auc: 0.917776
# [700]	valid's auc: 0.917782
# Early stopping, best iteration is:
# [676]	valid's auc: 0.917782
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.917525
# [200]	valid's auc: 0.918139
# [300]	valid's auc: 0.918377
# Early stopping, best iteration is:
# [297]	valid's auc: 0.918392
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.916387
# [200]	valid's auc: 0.917176
# [300]	valid's auc: 0.917513
# [400]	valid's auc: 0.917694
# [500]	valid's auc: 0.917794
# [600]	valid's auc: 0.917845
# [700]	valid's auc: 0.917875
# Early stopping, best iteration is:
# [685]	valid's auc: 0.917875
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.903699
# Early stopping, best iteration is:
# [119]	valid's auc: 0.903702
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.903724
# Early stopping, best iteration is:
# [92]	valid's auc: 0.903731
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.902359
# Early stopping, best iteration is:
# [86]	valid's auc: 0.902364
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.917496
# Early stopping, best iteration is:
# [85]	valid's auc: 0.917582
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.918493
# Early stopping, best iteration is:
# [98]	valid's auc: 0.918573
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.91787
# Early stopping, best iteration is:
# [94]	valid's auc: 0.917977
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.914728
# Early stopping, best iteration is:
# [138]	valid's auc: 0.914824
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.914758
# [200]	valid's auc: 0.915042
# [300]	valid's auc: 0.915361
# [400]	valid's auc: 0.915594
# [500]	valid's auc: 0.915763
# [600]	valid's auc: 0.915901
# [700]	valid's auc: 0.916009
# [800]	valid's auc: 0.916103
# [900]	valid's auc: 0.916181
# [1000]	valid's auc: 0.916254
# [1100]	valid's auc: 0.916312
# [1200]	valid's auc: 0.916388
# [1300]	valid's auc: 0.916473
# [1400]	valid's auc: 0.916543
# [1500]	valid's auc: 0.916581
# [1600]	valid's auc: 0.916633
# [1700]	valid's auc: 0.916681
# [1800]	valid's auc: 0.916719
# [1900]	valid's auc: 0.916755
# [2000]	valid's auc: 0.916777
# [2100]	valid's auc: 0.91681
# [2200]	valid's auc: 0.916834
# [2300]	valid's auc: 0.916853
# [2400]	valid's auc: 0.916882
# [2500]	valid's auc: 0.916896
# [2600]	valid's auc: 0.916917
# [2700]	valid's auc: 0.916928
# Early stopping, best iteration is:
# [2765]	valid's auc: 0.916944
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.914727
# [200]	valid's auc: 0.915086
# [300]	valid's auc: 0.915474
# [400]	valid's auc: 0.915793
# [500]	valid's auc: 0.916008
# [600]	valid's auc: 0.916195
# [700]	valid's auc: 0.916365
# [800]	valid's auc: 0.916555
# [900]	valid's auc: 0.91671
# [1000]	valid's auc: 0.916864
# [1100]	valid's auc: 0.91698
# [1200]	valid's auc: 0.917086
# [1300]	valid's auc: 0.917196
# [1400]	valid's auc: 0.917303
# [1500]	valid's auc: 0.917378
# [1600]	valid's auc: 0.91746
# [1700]	valid's auc: 0.917506
# [1800]	valid's auc: 0.917551
# [1900]	valid's auc: 0.917593
# [2000]	valid's auc: 0.917637
# [2100]	valid's auc: 0.917665
# [2200]	valid's auc: 0.917689
# [2300]	valid's auc: 0.917705
# [2400]	valid's auc: 0.917729
# [2500]	valid's auc: 0.91775
# [2600]	valid's auc: 0.917759
# [2700]	valid's auc: 0.917787
# [2800]	valid's auc: 0.917802
# [2900]	valid's auc: 0.917812
# [3000]	valid's auc: 0.917835
# Early stopping, best iteration is:
# [3034]	valid's auc: 0.917837
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [8]	valid's auc: 0.832675
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [8]	valid's auc: 0.832675
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [8]	valid's auc: 0.832675
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [10]	valid's auc: 0.832675
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [10]	valid's auc: 0.832675
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [10]	valid's auc: 0.832675
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.910535
# [200]	valid's auc: 0.910881
# Early stopping, best iteration is:
# [198]	valid's auc: 0.910881
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.910388
# Early stopping, best iteration is:
# [154]	valid's auc: 0.910682
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.910083
# Early stopping, best iteration is:
# [119]	valid's auc: 0.910609
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.916701
# [200]	valid's auc: 0.917375
# [300]	valid's auc: 0.917668
# [400]	valid's auc: 0.917941
# [500]	valid's auc: 0.918118
# [600]	valid's auc: 0.918276
# [700]	valid's auc: 0.918418
# [800]	valid's auc: 0.91856
# [900]	valid's auc: 0.918658
# [1000]	valid's auc: 0.918742
# [1100]	valid's auc: 0.918813
# [1200]	valid's auc: 0.918895
# [1300]	valid's auc: 0.918954
# [1400]	valid's auc: 0.919015
# [1500]	valid's auc: 0.919063
# [1600]	valid's auc: 0.919103
# [1700]	valid's auc: 0.919118
# [1800]	valid's auc: 0.919138
# [1900]	valid's auc: 0.919155
# [2000]	valid's auc: 0.919167
# [2100]	valid's auc: 0.919178
# [2200]	valid's auc: 0.91919
# [2300]	valid's auc: 0.919198
# [2400]	valid's auc: 0.91921
# [2500]	valid's auc: 0.91922
# [2600]	valid's auc: 0.919226
# [2700]	valid's auc: 0.919233
# [2800]	valid's auc: 0.919237
# [2900]	valid's auc: 0.919244
# [3000]	valid's auc: 0.919251
# [3100]	valid's auc: 0.919258
# [3200]	valid's auc: 0.91926
# Early stopping, best iteration is:
# [3216]	valid's auc: 0.919261
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.915367
# [200]	valid's auc: 0.915768
# [300]	valid's auc: 0.916031
# [400]	valid's auc: 0.916208
# [500]	valid's auc: 0.916317
# [600]	valid's auc: 0.916405
# [700]	valid's auc: 0.916481
# [800]	valid's auc: 0.916542
# [900]	valid's auc: 0.916595
# [1000]	valid's auc: 0.916638
# [1100]	valid's auc: 0.916677
# [1200]	valid's auc: 0.916708
# [1300]	valid's auc: 0.916735
# [1400]	valid's auc: 0.91676
# [1500]	valid's auc: 0.916776
# [1600]	valid's auc: 0.916793
# [1700]	valid's auc: 0.916808
# [1800]	valid's auc: 0.916829
# [1900]	valid's auc: 0.916846
# [2000]	valid's auc: 0.916859
# [2100]	valid's auc: 0.916871
# [2200]	valid's auc: 0.916883
# [2300]	valid's auc: 0.91689
# [2400]	valid's auc: 0.916899
# [2500]	valid's auc: 0.916905
# [2600]	valid's auc: 0.916913
# [2700]	valid's auc: 0.916923
# [2800]	valid's auc: 0.916929
# [2900]	valid's auc: 0.916934
# Early stopping, best iteration is:
# [2945]	valid's auc: 0.916936
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.91522
# [200]	valid's auc: 0.91617
# [300]	valid's auc: 0.916606
# [400]	valid's auc: 0.916956
# [500]	valid's auc: 0.917189
# [600]	valid's auc: 0.91736
# [700]	valid's auc: 0.917473
# [800]	valid's auc: 0.917584
# [900]	valid's auc: 0.917699
# [1000]	valid's auc: 0.917787
# [1100]	valid's auc: 0.91787
# [1200]	valid's auc: 0.917941
# [1300]	valid's auc: 0.917998
# [1400]	valid's auc: 0.918028
# [1500]	valid's auc: 0.918044
# [1600]	valid's auc: 0.918057
# Early stopping, best iteration is:
# [1592]	valid's auc: 0.918059
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [10]	valid's auc: 0.832675
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [10]	valid's auc: 0.832675
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [10]	valid's auc: 0.832675
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.916801
# [200]	valid's auc: 0.917267
# [300]	valid's auc: 0.917595
# [400]	valid's auc: 0.917834
# [500]	valid's auc: 0.918107
# [600]	valid's auc: 0.918441
# [700]	valid's auc: 0.918648
# [800]	valid's auc: 0.918892
# [900]	valid's auc: 0.919137
# [1000]	valid's auc: 0.919371
# [1100]	valid's auc: 0.919591
# [1200]	valid's auc: 0.919785
# [1300]	valid's auc: 0.919945
# [1400]	valid's auc: 0.920071
# [1500]	valid's auc: 0.920215
# [1600]	valid's auc: 0.920339
# [1700]	valid's auc: 0.920444
# [1800]	valid's auc: 0.920573
# [1900]	valid's auc: 0.920669
# [2000]	valid's auc: 0.920763
# [2100]	valid's auc: 0.920876
# [2200]	valid's auc: 0.920951
# [2300]	valid's auc: 0.921065
# [2400]	valid's auc: 0.921164
# [2500]	valid's auc: 0.921258
# [2600]	valid's auc: 0.92136
# [2700]	valid's auc: 0.921426
# [2800]	valid's auc: 0.92151
# [2900]	valid's auc: 0.921585
# [3000]	valid's auc: 0.921664
# [3100]	valid's auc: 0.921742
# [3200]	valid's auc: 0.921785
# [3300]	valid's auc: 0.921848
# [3400]	valid's auc: 0.921901
# [3500]	valid's auc: 0.921968
# [3600]	valid's auc: 0.922027
# [3700]	valid's auc: 0.922075
# [3800]	valid's auc: 0.922116
# Early stopping, best iteration is:
# [3804]	valid's auc: 0.922121
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.91712
# [200]	valid's auc: 0.917883
# [300]	valid's auc: 0.918282
# [400]	valid's auc: 0.918566
# [500]	valid's auc: 0.918643
# Early stopping, best iteration is:
# [480]	valid's auc: 0.918686
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.916844
# [200]	valid's auc: 0.91778
# [300]	valid's auc: 0.918565
# [400]	valid's auc: 0.91899
# [500]	valid's auc: 0.919384
# [600]	valid's auc: 0.91962
# [700]	valid's auc: 0.919889
# [800]	valid's auc: 0.9201
# [900]	valid's auc: 0.920328
# [1000]	valid's auc: 0.920515
# [1100]	valid's auc: 0.920713
# Early stopping, best iteration is:
# [1162]	valid's auc: 0.920861
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.911164
# Early stopping, best iteration is:
# [98]	valid's auc: 0.911164
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.91161
# Early stopping, best iteration is:
# [126]	valid's auc: 0.911665
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.910739
# Early stopping, best iteration is:
# [92]	valid's auc: 0.91074
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.913993
# Early stopping, best iteration is:
# [118]	valid's auc: 0.914112
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.914691
# [200]	valid's auc: 0.915424
# Early stopping, best iteration is:
# [221]	valid's auc: 0.91552
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.914135
# Early stopping, best iteration is:
# [154]	valid's auc: 0.914723
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [10]	valid's auc: 0.832675
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [10]	valid's auc: 0.832675
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [10]	valid's auc: 0.832675
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.911389
# Early stopping, best iteration is:
# [95]	valid's auc: 0.911389
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.911541
# Early stopping, best iteration is:
# [84]	valid's auc: 0.911556
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.910701
# Early stopping, best iteration is:
# [119]	valid's auc: 0.910719
# ...
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.914522
# [200]	valid's auc: 0.915014
# [300]	valid's auc: 0.915335
# [400]	valid's auc: 0.915532
# [500]	valid's auc: 0.915709
# [600]	valid's auc: 0.915825
# [700]	valid's auc: 0.916016
# Early stopping, best iteration is:
# [765]	valid's auc: 0.916074
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.911153
# Early stopping, best iteration is:
# [161]	valid's auc: 0.911453
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.910926
# [200]	valid's auc: 0.911164
# [300]	valid's auc: 0.91118
# [400]	valid's auc: 0.911187
# Early stopping, best iteration is:
# [395]	valid's auc: 0.911187
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.911151
# Early stopping, best iteration is:
# [161]	valid's auc: 0.911338
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.908368
# Early stopping, best iteration is:
# [116]	valid's auc: 0.908552
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.908202
# Early stopping, best iteration is:
# [128]	valid's auc: 0.908283
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.907696
# Early stopping, best iteration is:
# [133]	valid's auc: 0.907946
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.917024
# [200]	valid's auc: 0.917932
# [300]	valid's auc: 0.9183
# [400]	valid's auc: 0.918633
# [500]	valid's auc: 0.919078
# [600]	valid's auc: 0.919546
# [700]	valid's auc: 0.919826
# [800]	valid's auc: 0.920134
# Early stopping, best iteration is:
# [863]	valid's auc: 0.920271
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.918124
# [200]	valid's auc: 0.918979
# [300]	valid's auc: 0.919327
# Early stopping, best iteration is:
# [305]	valid's auc: 0.91936
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.917319
# [200]	valid's auc: 0.91843
# [300]	valid's auc: 0.918774
# [400]	valid's auc: 0.919263
# [500]	valid's auc: 0.919633
# [600]	valid's auc: 0.919967
# [700]	valid's auc: 0.9201
# Early stopping, best iteration is:
# [683]	valid's auc: 0.920112
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.917676
# [200]	valid's auc: 0.918488
# [300]	valid's auc: 0.918895
# [400]	valid's auc: 0.919006
# Early stopping, best iteration is:
# [391]	valid's auc: 0.919008
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.918275
# [200]	valid's auc: 0.919055
# [300]	valid's auc: 0.919378
# [400]	valid's auc: 0.919485
# Early stopping, best iteration is:
# [398]	valid's auc: 0.919486
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.91738
# [200]	valid's auc: 0.918294
# [300]	valid's auc: 0.918672
# [400]	valid's auc: 0.918903
# Early stopping, best iteration is:
# [459]	valid's auc: 0.918953
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.917346
# Early stopping, best iteration is:
# [84]	valid's auc: 0.917536
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.918296
# Early stopping, best iteration is:
# [121]	valid's auc: 0.91841
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.918278
# Early stopping, best iteration is:
# [131]	valid's auc: 0.918653
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.911217
# [200]	valid's auc: 0.911577
# [300]	valid's auc: 0.911703
# [400]	valid's auc: 0.911781
# [500]	valid's auc: 0.911839
# [600]	valid's auc: 0.911885
# [700]	valid's auc: 0.911915
# [800]	valid's auc: 0.911941
# [900]	valid's auc: 0.911963
# [1000]	valid's auc: 0.911975
# Early stopping, best iteration is:
# [1005]	valid's auc: 0.911978
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.91092
# [200]	valid's auc: 0.911503
# [300]	valid's auc: 0.911644
# [400]	valid's auc: 0.911718
# [500]	valid's auc: 0.911779
# [600]	valid's auc: 0.911828
# [700]	valid's auc: 0.911865
# [800]	valid's auc: 0.911888
# [900]	valid's auc: 0.911914
# [1000]	valid's auc: 0.911934
# [1100]	valid's auc: 0.911942
# Early stopping, best iteration is:
# [1079]	valid's auc: 0.911943
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.91066
# [200]	valid's auc: 0.911019
# Early stopping, best iteration is:
# [182]	valid's auc: 0.911035
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.916249
# [200]	valid's auc: 0.917341
# [300]	valid's auc: 0.91789
# [400]	valid's auc: 0.91812
# [500]	valid's auc: 0.918258
# [600]	valid's auc: 0.918354
# [700]	valid's auc: 0.91839
# Early stopping, best iteration is:
# [766]	valid's auc: 0.918425
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.917498
# [200]	valid's auc: 0.918249
# [300]	valid's auc: 0.918602
# [400]	valid's auc: 0.918861
# [500]	valid's auc: 0.919113
# [600]	valid's auc: 0.919277
# [700]	valid's auc: 0.919441
# [800]	valid's auc: 0.919482
# Early stopping, best iteration is:
# [779]	valid's auc: 0.919482
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.916634
# [200]	valid's auc: 0.917472
# [300]	valid's auc: 0.917891
# [400]	valid's auc: 0.918113
# Early stopping, best iteration is:
# [447]	valid's auc: 0.918209
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.913805
# [200]	valid's auc: 0.914449
# [300]	valid's auc: 0.914622
# [400]	valid's auc: 0.914709
# [500]	valid's auc: 0.914767
# [600]	valid's auc: 0.914814
# [700]	valid's auc: 0.914836
# [800]	valid's auc: 0.914873
# Early stopping, best iteration is:
# [793]	valid's auc: 0.914877
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.913131
# [200]	valid's auc: 0.913961
# [300]	valid's auc: 0.914051
# Early stopping, best iteration is:
# [327]	valid's auc: 0.914078
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.912608
# [200]	valid's auc: 0.913524
# [300]	valid's auc: 0.913734
# [400]	valid's auc: 0.913804
# [500]	valid's auc: 0.913872
# [600]	valid's auc: 0.913926
# [700]	valid's auc: 0.913961
# [800]	valid's auc: 0.913994
# [900]	valid's auc: 0.914022
# [1000]	valid's auc: 0.914047
# [1100]	valid's auc: 0.914069
# [1200]	valid's auc: 0.914092
# [1300]	valid's auc: 0.91411
# [1400]	valid's auc: 0.914135
# [1500]	valid's auc: 0.914155
# [1600]	valid's auc: 0.914171
# [1700]	valid's auc: 0.914187
# [1800]	valid's auc: 0.914204
# Early stopping, best iteration is:
# [1793]	valid's auc: 0.914206
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.919442
# [200]	valid's auc: 0.921069
# [300]	valid's auc: 0.921366
# [400]	valid's auc: 0.921614
# [500]	valid's auc: 0.921926
# Early stopping, best iteration is:
# [548]	valid's auc: 0.922036
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.919487
# [200]	valid's auc: 0.921062
# [300]	valid's auc: 0.921468
# Early stopping, best iteration is:
# [283]	valid's auc: 0.921539
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.920442
# [200]	valid's auc: 0.921952
# Early stopping, best iteration is:
# [266]	valid's auc: 0.923141
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.917099
# [200]	valid's auc: 0.918043
# [300]	valid's auc: 0.918358
# [400]	valid's auc: 0.91867
# [500]	valid's auc: 0.918969
# [600]	valid's auc: 0.919251
# [700]	valid's auc: 0.919642
# [800]	valid's auc: 0.91998
# Early stopping, best iteration is:
# [869]	valid's auc: 0.920182
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.917795
# Early stopping, best iteration is:
# [168]	valid's auc: 0.918492
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.916333
# [200]	valid's auc: 0.917437
# [300]	valid's auc: 0.91783
# [400]	valid's auc: 0.918226
# [500]	valid's auc: 0.918886
# Early stopping, best iteration is:
# [551]	valid's auc: 0.919115
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.910952
# [200]	valid's auc: 0.912135
# Early stopping, best iteration is:
# [227]	valid's auc: 0.912262
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.911195
# [200]	valid's auc: 0.912001
# [300]	valid's auc: 0.912432
# Early stopping, best iteration is:
# [350]	valid's auc: 0.91259
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.910407
# [200]	valid's auc: 0.911332
# Early stopping, best iteration is:
# [265]	valid's auc: 0.9115
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.916163
# [200]	valid's auc: 0.91734
# [300]	valid's auc: 0.917613
# [400]	valid's auc: 0.917688
# [500]	valid's auc: 0.917761
# [600]	valid's auc: 0.91781
# [700]	valid's auc: 0.917865
# [800]	valid's auc: 0.9179
# [900]	valid's auc: 0.917938
# [1000]	valid's auc: 0.917959
# Early stopping, best iteration is:
# [1058]	valid's auc: 0.917981
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.916526
# [200]	valid's auc: 0.917495
# [300]	valid's auc: 0.917782
# [400]	valid's auc: 0.917904
# [500]	valid's auc: 0.918045
# [600]	valid's auc: 0.918178
# [700]	valid's auc: 0.918264
# [800]	valid's auc: 0.918352
# [900]	valid's auc: 0.918431
# [1000]	valid's auc: 0.918514
# [1100]	valid's auc: 0.918588
# Early stopping, best iteration is:
# [1137]	valid's auc: 0.918613
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.915867
# [200]	valid's auc: 0.916924
# [300]	valid's auc: 0.917093
# [400]	valid's auc: 0.917263
# [500]	valid's auc: 0.917421
# [600]	valid's auc: 0.917527
# [700]	valid's auc: 0.917653
# [800]	valid's auc: 0.917762
# [900]	valid's auc: 0.917861
# [1000]	valid's auc: 0.917967
# [1100]	valid's auc: 0.918051
# [1200]	valid's auc: 0.918165
# [1300]	valid's auc: 0.918232
# [1400]	valid's auc: 0.918294
# Early stopping, best iteration is:
# [1451]	valid's auc: 0.918303
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.917219
# [200]	valid's auc: 0.918634
# [300]	valid's auc: 0.919298
# [400]	valid's auc: 0.919814
# [500]	valid's auc: 0.920237
# [600]	valid's auc: 0.920518
# [700]	valid's auc: 0.920804
# [800]	valid's auc: 0.921033
# [900]	valid's auc: 0.921194
# [1000]	valid's auc: 0.921328
# [1100]	valid's auc: 0.92145
# [1200]	valid's auc: 0.921546
# [1300]	valid's auc: 0.921626
# [1400]	valid's auc: 0.921704
# [1500]	valid's auc: 0.921777
# [1600]	valid's auc: 0.921824
# [1700]	valid's auc: 0.921865
# [1800]	valid's auc: 0.921911
# [1900]	valid's auc: 0.921942
# [2000]	valid's auc: 0.921977
# [2100]	valid's auc: 0.921998
# Early stopping, best iteration is:
# [2162]	valid's auc: 0.922012
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.917705
# [200]	valid's auc: 0.918516
# [300]	valid's auc: 0.919089
# [400]	valid's auc: 0.919492
# [500]	valid's auc: 0.919767
# [600]	valid's auc: 0.919939
# [700]	valid's auc: 0.920099
# [800]	valid's auc: 0.920201
# [900]	valid's auc: 0.92029
# [1000]	valid's auc: 0.920416
# [1100]	valid's auc: 0.920552
# [1200]	valid's auc: 0.920667
# [1300]	valid's auc: 0.920736
# [1400]	valid's auc: 0.920853
# [1500]	valid's auc: 0.920943
# [1600]	valid's auc: 0.921001
# [1700]	valid's auc: 0.92108
# Early stopping, best iteration is:
# [1749]	valid's auc: 0.921116
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.917476
# [200]	valid's auc: 0.918278
# [300]	valid's auc: 0.918744
# [400]	valid's auc: 0.919099
# [500]	valid's auc: 0.919389
# [600]	valid's auc: 0.91956
# [700]	valid's auc: 0.919797
# [800]	valid's auc: 0.91996
# [900]	valid's auc: 0.920117
# [1000]	valid's auc: 0.92024
# [1100]	valid's auc: 0.920392
# [1200]	valid's auc: 0.920514
# [1300]	valid's auc: 0.920617
# [1400]	valid's auc: 0.92073
# [1500]	valid's auc: 0.920827
# [1600]	valid's auc: 0.92086
# [1700]	valid's auc: 0.920888
# [1800]	valid's auc: 0.920905
# [1900]	valid's auc: 0.920908
# [2000]	valid's auc: 0.920943
# Early stopping, best iteration is:
# [2003]	valid's auc: 0.920944
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.917912
# [200]	valid's auc: 0.918949
# [300]	valid's auc: 0.919546
# [400]	valid's auc: 0.920023
# [500]	valid's auc: 0.920468
# [600]	valid's auc: 0.920844
# [700]	valid's auc: 0.921037
# [800]	valid's auc: 0.921196
# [900]	valid's auc: 0.921402
# Early stopping, best iteration is:
# [950]	valid's auc: 0.921511
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.918467
# [200]	valid's auc: 0.919249
# [300]	valid's auc: 0.919684
# [400]	valid's auc: 0.919848
# Early stopping, best iteration is:
# [376]	valid's auc: 0.919888
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.91773
# [200]	valid's auc: 0.918727
# [300]	valid's auc: 0.919435
# [400]	valid's auc: 0.919962
# [500]	valid's auc: 0.920381
# Early stopping, best iteration is:
# [554]	valid's auc: 0.920563
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.914644
# Early stopping, best iteration is:
# [75]	valid's auc: 0.914756
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.914624
# Early stopping, best iteration is:
# [104]	valid's auc: 0.914673
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.914928
# [200]	valid's auc: 0.915538
# Early stopping, best iteration is:
# [238]	valid's auc: 0.915927
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.917559
# [200]	valid's auc: 0.918292
# [300]	valid's auc: 0.918813
# [400]	valid's auc: 0.919086
# [500]	valid's auc: 0.919384
# [600]	valid's auc: 0.919624
# [700]	valid's auc: 0.91983
# [800]	valid's auc: 0.920062
# [900]	valid's auc: 0.920236
# [1000]	valid's auc: 0.920435
# [1100]	valid's auc: 0.920559
# [1200]	valid's auc: 0.920675
# [1300]	valid's auc: 0.920765
# [1400]	valid's auc: 0.920888
# [1500]	valid's auc: 0.920968
# [1600]	valid's auc: 0.921051
# [1700]	valid's auc: 0.921128
# [1800]	valid's auc: 0.921204
# [1900]	valid's auc: 0.921276
# [2000]	valid's auc: 0.921332
# [2100]	valid's auc: 0.92138
# [2200]	valid's auc: 0.92143
# [2300]	valid's auc: 0.921475
# [2400]	valid's auc: 0.921509
# [2500]	valid's auc: 0.921545
# [2600]	valid's auc: 0.921596
# Early stopping, best iteration is:
# [2615]	valid's auc: 0.9216
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.918119
# [200]	valid's auc: 0.918969
# [300]	valid's auc: 0.919471
# [400]	valid's auc: 0.919831
# [500]	valid's auc: 0.920142
# [600]	valid's auc: 0.920345
# [700]	valid's auc: 0.920494
# [800]	valid's auc: 0.920641
# [900]	valid's auc: 0.920722
# [1000]	valid's auc: 0.92077
# Early stopping, best iteration is:
# [976]	valid's auc: 0.920782
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.917508
# [200]	valid's auc: 0.918529
# [300]	valid's auc: 0.919105
# [400]	valid's auc: 0.919422
# [500]	valid's auc: 0.919716
# [600]	valid's auc: 0.919934
# [700]	valid's auc: 0.920098
# [800]	valid's auc: 0.920249
# [900]	valid's auc: 0.920345
# [1000]	valid's auc: 0.920481
# [1100]	valid's auc: 0.920603
# [1200]	valid's auc: 0.920716
# [1300]	valid's auc: 0.92081
# [1400]	valid's auc: 0.920908
# [1500]	valid's auc: 0.920992
# [1600]	valid's auc: 0.92108
# [1700]	valid's auc: 0.921148
# [1800]	valid's auc: 0.921211
# Early stopping, best iteration is:
# [1858]	valid's auc: 0.921248
# [Parallel(n_jobs=1)]: Done 300 out of 300 | elapsed:  5.0min finished
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.922665
# [200]	valid's auc: 0.925268
# [300]	valid's auc: 0.926173
# [400]	valid's auc: 0.927112
# [500]	valid's auc: 0.927544
# Early stopping, best iteration is:
# [550]	valid's auc: 0.927737
# Best score reached: 0.8064773837609197 with params: {'colsample_bytree': 0.7173613575636579, 'min_child_samples': 134, 'min_child_weight': 1e-05, 'num_leaves': 14, 'reg_alpha': 0, 'reg_lambda': 20, 'subsample': 0.5813098915332424}

# %%
opt_parameters = {'colsample_bytree': 0.7173613575636579, 
                  'min_child_samples': 134, 
                  'min_child_weight': 1e-05, 
                  'num_leaves': 14, 
                  'reg_alpha': 0, 
                  'reg_lambda': 20, 
                  'subsample': 0.5813098915332424} 

#{'colsample_bytree': 0.9234, 'min_child_samples': 399, 'min_child_weight': 0.1, 'num_leaves': 13, 'reg_alpha': 2, 'reg_lambda': 5, 'subsample': 0.855}

# %% [markdown]
# ### Tune the weights of unbalanced classes

# %%
clf_sw = lgb.LGBMClassifier(**clf.get_params())
#set optimal parameters
clf_sw.set_params(**opt_parameters)
# Out:
# LGBMClassifier(colsample_bytree=0.7173613575636579, metric='None',
#                min_child_samples=134, min_child_weight=1e-05, n_estimators=5000,
#                n_jobs=4, num_leaves=14, random_state=314, reg_alpha=0,
#                reg_lambda=20, subsample=0.5813098915332424)

# %%
gs_sample_weight = GridSearchCV(estimator=clf_sw, 
                                param_grid={'scale_pos_weight':[1, 2, 6, 12]},
                                scoring='f1',
                                cv=5,
                                refit=True,
                                verbose=True)

# %%
gs_sample_weight.fit(tmp_x_train, y_train, **fit_params)
print('Best score reached: {} with params: {} '.format(gs_sample_weight.best_score_, gs_sample_weight.best_params_))
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Training until validation scores don't improve for 30 rounds
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [100]	valid's auc: 0.922348
# [200]	valid's auc: 0.924951
# [300]	valid's auc: 0.925594
# [400]	valid's auc: 0.926196
# [500]	valid's auc: 0.926426
# Early stopping, best iteration is:
# [517]	valid's auc: 0.926453
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.922415
# [200]	valid's auc: 0.924855
# [300]	valid's auc: 0.925498
# [400]	valid's auc: 0.925857
# [500]	valid's auc: 0.926217
# [600]	valid's auc: 0.926336
# Early stopping, best iteration is:
# [588]	valid's auc: 0.9264
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.921934
# [200]	valid's auc: 0.924281
# [300]	valid's auc: 0.925527
# Early stopping, best iteration is:
# [364]	valid's auc: 0.925908
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.922598
# [200]	valid's auc: 0.924977
# [300]	valid's auc: 0.926078
# [400]	valid's auc: 0.926579
# Early stopping, best iteration is:
# [413]	valid's auc: 0.926631
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.922128
# [200]	valid's auc: 0.924662
# [300]	valid's auc: 0.925674
# [400]	valid's auc: 0.926291
# [500]	valid's auc: 0.926602
# Early stopping, best iteration is:
# [566]	valid's auc: 0.926841
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.923232
# [200]	valid's auc: 0.925852
# [300]	valid's auc: 0.926281
# Early stopping, best iteration is:
# [271]	valid's auc: 0.926433
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.922776
# [200]	valid's auc: 0.92538
# [300]	valid's auc: 0.925787
# [400]	valid's auc: 0.925999
# Early stopping, best iteration is:
# [392]	valid's auc: 0.926064
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.922588
# [200]	valid's auc: 0.924951
# [300]	valid's auc: 0.925979
# [400]	valid's auc: 0.926364
# [500]	valid's auc: 0.926688
# Early stopping, best iteration is:
# [506]	valid's auc: 0.926715
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.923255
# [200]	valid's auc: 0.925848
# [300]	valid's auc: 0.926755
# Early stopping, best iteration is:
# [353]	valid's auc: 0.927258
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.923287
# [200]	valid's auc: 0.925628
# [300]	valid's auc: 0.926397
# [400]	valid's auc: 0.926698
# Early stopping, best iteration is:
# [426]	valid's auc: 0.926858
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.92324
# [200]	valid's auc: 0.926261
# [300]	valid's auc: 0.926737
# Early stopping, best iteration is:
# [363]	valid's auc: 0.926937
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.922672
# [200]	valid's auc: 0.925136
# [300]	valid's auc: 0.925682
# Early stopping, best iteration is:
# [345]	valid's auc: 0.925877
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.922391
# [200]	valid's auc: 0.925133
# [300]	valid's auc: 0.925826
# [400]	valid's auc: 0.926099
# [500]	valid's auc: 0.926161
# Early stopping, best iteration is:
# [480]	valid's auc: 0.926226
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.924268
# [200]	valid's auc: 0.926398
# [300]	valid's auc: 0.926998
# [400]	valid's auc: 0.927512
# Early stopping, best iteration is:
# [414]	valid's auc: 0.927529
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.922881
# [200]	valid's auc: 0.925444
# [300]	valid's auc: 0.925822
# Early stopping, best iteration is:
# [276]	valid's auc: 0.925951
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.922948
# [200]	valid's auc: 0.925686
# [300]	valid's auc: 0.926438
# Early stopping, best iteration is:
# [322]	valid's auc: 0.926633
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.922407
# [200]	valid's auc: 0.92511
# [300]	valid's auc: 0.92581
# Early stopping, best iteration is:
# [321]	valid's auc: 0.925981
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.922589
# [200]	valid's auc: 0.925172
# [300]	valid's auc: 0.925629
# Early stopping, best iteration is:
# [344]	valid's auc: 0.925929
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.9241
# [200]	valid's auc: 0.926652
# [300]	valid's auc: 0.92698
# Early stopping, best iteration is:
# [287]	valid's auc: 0.927066
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.92278
# [200]	valid's auc: 0.925551
# [300]	valid's auc: 0.925891
# Early stopping, best iteration is:
# [271]	valid's auc: 0.925917
# Training until validation scores don't improve for 30 rounds
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed:   18.6s finished
# [100]	valid's auc: 0.923868
# [200]	valid's auc: 0.926333
# [300]	valid's auc: 0.927187
# Early stopping, best iteration is:
# [367]	valid's auc: 0.927437
# Best score reached: 0.7211768617287371 with params: {'scale_pos_weight': 2}

# %% [markdown]
# ### Build final model

# %%
#Configure from the HP optimisation
clf_final = lgb.LGBMClassifier(**gs.best_estimator_.get_params())

#Configure locally from hardcoded values
#clf_final = lgb.LGBMClassifier(**clf.get_params())

#set optimal parameters
clf_final.set_params(**opt_parameters)

#Train the final model with learning rate decay
clf_final.fit(tmp_x_train, y_train, **fit_params, callbacks=[lgb.reset_parameter(learning_rate=learning_rate_010_decay_power_0995)])
# Out:
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.921265
# [200]	valid's auc: 0.923487
# [300]	valid's auc: 0.924268
# [400]	valid's auc: 0.92454
# [500]	valid's auc: 0.924644
# [600]	valid's auc: 0.924709
# [700]	valid's auc: 0.924761
# Early stopping, best iteration is:
# [752]	valid's auc: 0.924772
# LGBMClassifier(colsample_bytree=0.7173613575636579, metric='None',
#                min_child_samples=134, min_child_weight=1e-05, n_estimators=5000,
#                n_jobs=4, num_leaves=14, random_state=314, reg_alpha=0,
#                reg_lambda=20, subsample=0.5813098915332424)

# %%
qq = clf_final.predict(tmp_x_valid)
print(f"LightGBM F1 Score: {f1_score(y_valid, qq, average='micro')}")
#0.86
# Out:
# LightGBM F1 Score: 0.8661931272797082

# %%
preds3 = clf_final.predict(x_test)
sample_submission['prediction'] = preds3
sample_submission.to_csv('submission_pred3.csv', index=False)

# 0.86

# %% [markdown]
# # 베이지안 파라미터 옵티마이제이션

# %%
#building models
import lightgbm as lgb
import xgboost as xgb
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
import time
import sys

#tuning hyperparameters
from bayes_opt import BayesianOptimization
from skopt  import BayesSearchCV 

#metrics 
from sklearn.metrics import roc_auc_score, roc_curve
import shap

# %%
from sklearn.metrics import f1_score

def lgb_f1_score(y_hat, data):
    y_true = data.get_label()
    y_hat = np.round(y_hat) # scikits f1 doesn't like probabilities
    return 'f1', f1_score(y_true, y_hat), True

# %%
def bayes_parameter_opt_lgb(X, y, init_round=20, opt_round=30, n_folds=5, random_seed=6, n_estimators=10000,
                            learning_rate=0.05, output_process=False):
    # prepare data

    train_data = lgb.Dataset(data=X, label=y)
    # parameters

    def lgb_eval(num_leaves, feature_fraction, bagging_fraction, max_depth, 
                 lambda_l1, lambda_l2, min_split_gain, min_child_weight):
        
        global cv_result

        params = {'objective':'binary','num_iterations':1000, 'learning_rate':0.05,
                  'early_stopping_round':100, 'metric':'binary_logloss'} #rmse
        params["num_leaves"] = int(round(num_leaves))
        params['feature_fraction'] = max(min(feature_fraction, 1), 0)
        params['bagging_fraction'] = max(min(bagging_fraction, 1), 0)
        params['max_depth'] = int(round(max_depth))
        params['lambda_l1'] = max(lambda_l1, 0)
        params['lambda_l2'] = max(lambda_l2, 0)
        params['min_split_gain'] = min_split_gain
        params['min_child_weight'] = min_child_weight
        
        cv_result = lgb.cv(params, train_data, nfold=3, seed=random_seed,
                           stratified=False, verbose_eval =200, metrics=['binary_logloss']) #rmse

        return min(cv_result['binary_logloss-mean']) 

    # setting range of the parameters
    lgbBO = BayesianOptimization(lgb_eval, {'num_leaves': (24, 45),
                                            'feature_fraction': (0.1, 0.9),
                                            'bagging_fraction': (0.5, 1),
                                            'max_depth': (5, 8.99),
                                            'lambda_l1': (0, 5),
                                            'lambda_l2': (0, 3),
                                            'min_split_gain': (0.001, 0.1),
                                            'min_child_weight': (5, 60)}, random_state=0)
    # optimize
    lgbBO.maximize(init_points=init_round, n_iter=opt_round)
    
    # output optimization process
    if output_process==True: lgbBO.points_to_csv("bayes_opt_result.csv")
    
    # return
    return lgbBO

opt_params = bayes_parameter_opt_lgb(tmp_x_train, y_train, init_round=5, opt_round=10, n_folds=3,
                                     random_seed=6, n_estimators=10000, learning_rate=0.05)
# Out:
# |   iter    |  target   | baggin... | featur... | lambda_l1 | lambda_l2 | max_depth | min_ch... | min_sp... | num_le... |
# -------------------------------------------------------------------------------------------------------------------------
# [200]	cv_agg's binary_logloss: 0.305371 + 0.00716862
# [400]	cv_agg's binary_logloss: 0.303903 + 0.00741055
# [600]	cv_agg's binary_logloss: 0.303098 + 0.00741458
# [800]	cv_agg's binary_logloss: 0.302444 + 0.00740958
# [1000]	cv_agg's binary_logloss: 0.301924 + 0.00739532
# |  1        |  0.3019   |  0.7744   |  0.6722   |  3.014    |  1.635    |  6.69     |  40.52    |  0.04432  |  42.73    |
# [200]	cv_agg's binary_logloss: 0.310054 + 0.00746455
# [400]	cv_agg's binary_logloss: 0.308554 + 0.00785947
# [600]	cv_agg's binary_logloss: 0.30809 + 0.00787684
# [800]	cv_agg's binary_logloss: 0.307634 + 0.00787019
# [1000]	cv_agg's binary_logloss: 0.30726 + 0.00786974
# |  2        |  0.3073   |  0.9818   |  0.4068   |  3.959    |  1.587    |  7.266    |  55.91    |  0.008033 |  25.83    |
# [200]	cv_agg's binary_logloss: 0.308119 + 0.00727592
# [400]	cv_agg's binary_logloss: 0.306917 + 0.00743599
# [600]	cv_agg's binary_logloss: 0.306149 + 0.00750106
# [800]	cv_agg's binary_logloss: 0.305567 + 0.00753973
# [1000]	cv_agg's binary_logloss: 0.305103 + 0.00760087
# |  3        |  0.3051   |  0.5101   |  0.7661   |  3.891    |  2.61     |  8.905    |  48.95    |  0.04669  |  40.39    |
# [200]	cv_agg's binary_logloss: 0.301738 + 0.00605881
# [400]	cv_agg's binary_logloss: 0.299214 + 0.00638553
# [600]	cv_agg's binary_logloss: 0.298327 + 0.00637071
# [800]	cv_agg's binary_logloss: 0.29756 + 0.00642364
# [1000]	cv_agg's binary_logloss: 0.296938 + 0.00645225
# |  4        |  0.2969   |  0.5591   |  0.6119   |  0.7168   |  2.834    |  7.082    |  27.81    |  0.02719  |  40.26    |
# [200]	cv_agg's binary_logloss: 0.304675 + 0.00720238
# [400]	cv_agg's binary_logloss: 0.303111 + 0.00766027
# [600]	cv_agg's binary_logloss: 0.302224 + 0.00773153
# [800]	cv_agg's binary_logloss: 0.301435 + 0.00769982
# [1000]	cv_agg's binary_logloss: 0.300828 + 0.00768233
# |  5        |  0.3008   |  0.7281   |  0.5547   |  0.09395  |  1.853    |  7.442    |  38.93    |  0.09443  |  38.32    |
# [200]	cv_agg's binary_logloss: 0.31125 + 0.00708102
# [400]	cv_agg's binary_logloss: 0.309874 + 0.007226
# [600]	cv_agg's binary_logloss: 0.30933 + 0.00721302
# [800]	cv_agg's binary_logloss: 0.308879 + 0.00718773
# [1000]	cv_agg's binary_logloss: 0.308504 + 0.00716958
# |  6        |  0.3085   |  1.0      |  0.8663   |  5.0      |  0.0      |  5.0      |  60.0     |  0.1      |  45.0     |
# [200]	cv_agg's binary_logloss: 0.32338 + 0.00528713
# [400]	cv_agg's binary_logloss: 0.312057 + 0.00667976
# [600]	cv_agg's binary_logloss: 0.309731 + 0.00706046
# [800]	cv_agg's binary_logloss: 0.308772 + 0.00723763
# [1000]	cv_agg's binary_logloss: 0.308263 + 0.00736592
# |  7        |  0.3083   |  1.0      |  0.1      |  0.0      |  3.0      |  5.0      |  60.0     |  0.001    |  35.36    |
# [200]	cv_agg's binary_logloss: 0.324823 + 0.0051657
# [400]	cv_agg's binary_logloss: 0.31342 + 0.00662193
# [600]	cv_agg's binary_logloss: 0.311092 + 0.00699047
# [800]	cv_agg's binary_logloss: 0.31024 + 0.00720766
# [1000]	cv_agg's binary_logloss: 0.309902 + 0.00731998
# |  8        |  0.3099   |  0.5      |  0.1      |  5.0      |  0.0      |  5.0      |  60.0     |  0.001    |  33.71    |
# [200]	cv_agg's binary_logloss: 0.324812 + 0.0051673
# [400]	cv_agg's binary_logloss: 0.313374 + 0.00665499
# [600]	cv_agg's binary_logloss: 0.311059 + 0.00701923
# [800]	cv_agg's binary_logloss: 0.310143 + 0.00723345
# [1000]	cv_agg's binary_logloss: 0.3098 + 0.00735279
# |  9        |  0.3098   |  0.5      |  0.1      |  5.0      |  0.0      |  8.99     |  60.0     |  0.001    |  34.82    |
# [200]	cv_agg's binary_logloss: 0.324918 + 0.00519319
# [400]	cv_agg's binary_logloss: 0.313614 + 0.00668776
# [600]	cv_agg's binary_logloss: 0.311367 + 0.00700051
# [800]	cv_agg's binary_logloss: 0.310829 + 0.00710427
# [1000]	cv_agg's binary_logloss: 0.310558 + 0.00720321
# |  10       |  0.3106   |  0.5      |  0.1      |  5.0      |  0.0      |  5.0      |  60.0     |  0.1      |  24.0     |
# [200]	cv_agg's binary_logloss: 0.311144 + 0.00691668
# [400]	cv_agg's binary_logloss: 0.310355 + 0.00697589
# [600]	cv_agg's binary_logloss: 0.309835 + 0.00694163
# [800]	cv_agg's binary_logloss: 0.3094 + 0.00692015
# [1000]	cv_agg's binary_logloss: 0.309044 + 0.00690146
# |  11       |  0.309    |  0.5      |  0.9      |  5.0      |  0.0      |  8.99     |  60.0     |  0.1      |  24.0     |
# [200]	cv_agg's binary_logloss: 0.312719 + 0.00509361
# [400]	cv_agg's binary_logloss: 0.29669 + 0.00633058
# [600]	cv_agg's binary_logloss: 0.29264 + 0.00685777
# [800]	cv_agg's binary_logloss: 0.291864 + 0.00690636
# [1000]	cv_agg's binary_logloss: 0.291662 + 0.00690604
# |  12       |  0.2917   |  1.0      |  0.1      |  5.0      |  0.0      |  8.99     |  5.0      |  0.1      |  24.0     |
# [200]	cv_agg's binary_logloss: 0.32274 + 0.00526973
# [400]	cv_agg's binary_logloss: 0.311868 + 0.00661285
# [600]	cv_agg's binary_logloss: 0.309819 + 0.00710193
# [800]	cv_agg's binary_logloss: 0.309303 + 0.00721406
# [1000]	cv_agg's binary_logloss: 0.308953 + 0.00728193
# |  13       |  0.309    |  0.5      |  0.1      |  0.0      |  0.0      |  5.0      |  60.0     |  0.1      |  24.0     |
# [200]	cv_agg's binary_logloss: 0.324918 + 0.00519319
# [400]	cv_agg's binary_logloss: 0.313614 + 0.00668776
# [600]	cv_agg's binary_logloss: 0.311367 + 0.00700051
# [800]	cv_agg's binary_logloss: 0.310829 + 0.00710427
# [1000]	cv_agg's binary_logloss: 0.310558 + 0.00720321
# |  14       |  0.3106   |  0.5      |  0.1      |  5.0      |  0.0      |  5.0      |  60.0     |  0.1      |  27.37    |
# [200]	cv_agg's binary_logloss: 0.325641 + 0.00519133
# [400]	cv_agg's binary_logloss: 0.313927 + 0.00670328
# [600]	cv_agg's binary_logloss: 0.311544 + 0.00698739
# [800]	cv_agg's binary_logloss: 0.310999 + 0.00712911
# [1000]	cv_agg's binary_logloss: 0.310727 + 0.00722327
# |  15       |  0.3107   |  0.5      |  0.1      |  5.0      |  3.0      |  5.0      |  60.0     |  0.1      |  24.51    |
# =========================================================================================================================

# %%
params = opt_params.max['params']

# %%
params
# Out:
# {'bagging_fraction': 0.5,
#  'feature_fraction': 0.1,
#  'lambda_l1': 5.0,
#  'lambda_l2': 3.0,
#  'max_depth': 5.0,
#  'min_child_weight': 60.0,
#  'min_split_gain': 0.1,
#  'num_leaves': 24.506343212578575}

# %%
params = {
    "objective" : "binary",
    "metric" : "binary_logloss", # rmse
    "bagging_frequency" : 5,
    "bagging_seed" : 2018,
    "verbosity" : -1,

    # Selected rounded-off params
    'bagging_fraction': 0.5,
    'feature_fraction': 0.1,
    'lambda_l1': 5.0,
    'lambda_l2': 3.0,
    'max_depth': 5,
    'min_child_weight': 60.0,
    'min_split_gain': 0.1,
    'num_leaves': 25
}

# %%
params = {
    "objective" : "binary",
    "metric" : "binary_logloss",
    "bagging_frequency" : 5,
    "bagging_seed" : 2018,
    "verbosity" : -1,

    # Selected rounded-off params
    'bagging_fraction': 0.5,
    'feature_fraction': 0.1,
    'lambda_l1': 5.0,
    'lambda_l2': 3.0,
    'max_depth': 5,
    'min_child_weight': 60.0,
    'min_split_gain': 0.1,
    'num_leaves': 45
}

# %%
#train_test_split 
X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.3,random_state=0)
#converting the dataset into proper LGB format 
d_train=lgb.Dataset(X_train, label=y_train)
#Specifying the parameter
params={}
params['learning_rate']=0.03
params['boosting_type']='gbdt' #GradientBoostingDecisionTree
params['objective']='binary' #Binary target feature
params['metric']='binary_logloss' #metric for binary classification
params['max_depth']=10
#train the model 
clf=lgb.train(params,d_train,100) #train the model on 100 epocs
#prediction on the test set
y_pred=clf.predict(X_test)

# %%
import lightgbm as lgb
d_train = lgb.Dataset(tmp_x_train, label=y_train)
d_test = lgb.Dataset(tmp_x_valid, label=y_valid)
clf = lgb.train(params, d_train, 1000, d_test, verbose_eval=100, early_stopping_rounds=100)

y_pred = clf.predict(x_valid)
# Out:
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.322877
# [200]	valid_0's binary_logloss: 0.305375
# [300]	valid_0's binary_logloss: 0.301182
# [400]	valid_0's binary_logloss: 0.300576
# [500]	valid_0's binary_logloss: 0.300269
# [600]	valid_0's binary_logloss: 0.300054
# [700]	valid_0's binary_logloss: 0.299816
# [800]	valid_0's binary_logloss: 0.299639
# [900]	valid_0's binary_logloss: 0.299427
# [1000]	valid_0's binary_logloss: 0.299261
# Did not meet early stopping. Best iteration is:
# [997]	valid_0's binary_logloss: 0.299261

# %%
#rounding the values
y_pred=y_pred.round(0)
#converting from float to integer
y_pred=y_pred.astype(int)
f1 = f1_score(y_valid, y_pred, average='micro')
print('-F1 Score: ', f1)
# Out:
# -F1 Score:  0.8608178153196391

# %%
y_pred3 = clf.predict(x_test)
#rounding the values
y_pred3=y_pred3.round(0)
#converting from float to integer
y_pred3=y_pred3.astype(int)

# %%
sample_submission['prediction'] = y_pred3
sample_submission.to_csv('submission_pred4.csv', index=False)

# 이거 아직 제출 못해봄
